# %% [markdown]
# # 데이터 크롤링

# %% [markdown]
# ## 1. 크롤링이란?
#     크롤러(crawler)는 자동화된 방법으로 웹을 탐색하는 컴퓨터 프로그램
#
#     '웹 크롤링'(web crawling)??
#
#     '데이터 크롤링'(data crawling)!!

# %% [markdown]
# #### 우리는 매일 크롤러도 사용하고 있습니다.

# %% [markdown]
# ## 2. 웹 크롤링
#     웹 서비스 내 정보를 수집하는 일
#
#     필요한 정보가 있다면?
#     API 확인 -> 없으면 직접 크롤링
#
#     다만 서비스 제공자의 입장에서는??

# %% [markdown]
# ### 웹 서핑을 하는 의식의 흐름
#     브라우저 오픈
#     원하는 인터넷페이지 주소 입력
#     화면이 열리면 찾고자 하는 정보를 스크롤 하면서 찾기
#     문자, 그림, 동영상 조회

# %% [markdown]
# ### 웹 크롤링 하는 의식의 흐름
#     정보를 가져오고자 하는 url 정의
#     url 정보로 requests로 정보 요청
#     text 정보를 html로 변환
#     html에서 우리가 필요한 정보만 선별

# %% [markdown]
# ### 웹 크롤링을 위해 BeautifulSoup 사용
#     requests는 요청을 받기는 하지만 text로만 받음
#     API는 통신을 위해 정형화 된 데이터 형태의 text
#     우리가 원하는 데이터로 가공하기 위해 편의상 html로 변환
#     text를 html로 변환하는 모듈이 beautifulSoup

# %% [markdown]
# ## 간단한 네이터 크롤링으로 기본 개념잡기

# %%
immp

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://naver.com'
# Out:
# [<span>뉴스스탠드 바로가기</span>,
#  <span>주제별캐스트 바로가기</span>,
#  <span>타임스퀘어 바로가기</span>,
#  <span>쇼핑캐스트 바로가기</span>,
#  <span>로그인 바로가기</span>,
#  <span>브라우저에서 다 되는 네이버 웨일!</span>,
#  <span>다운로드</span>,
#  <span class="blind">NAVER whale</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>]

# %%
response = requests.get(url)    
html
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
html = BeautifulSoup(response.text, "html.parser")

# %%
html.select('span')[0:10]
# Out:
# [<span>뉴스스탠드 바로가기</span>,
#  <span>주제별캐스트 바로가기</span>,
#  <span>타임스퀘어 바로가기</span>,
#  <span>쇼핑캐스트 바로가기</span>,
#  <span>로그인 바로가기</span>,
#  <span>브라우저에서 다 되는 네이버 웨일!</span>,
#  <span>다운로드</span>,
#  <span class="blind">NAVER whale</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>]

# %% [markdown]
# ### 실제 개발자가 작성한 코드로 확인된다
#     정제되지 않은 데이터로 가독성이 좋지 않음
#     우리는 이 중에서 우리가 원하는 정보를 선별해서 가져오는 작업을 진행합니다.
#     그러기에 html의 기본 구성을 살펴보도록 하겠습니다.

# %% [markdown]
# #### 웹 페이지의 구성
#     HTML(Hyper Text Markup Language)
#     www 를 구성하는데 사용하는 국제표준 언어로서 컨텐츠와 레이아웃을 담고 있다
#
#     <태그>내용</태그>
# <tag이름 class="class이름1 class이름2" id="주민번호" href="주소"></tag이름>
#
#     형태나 속성을 묘사하기 위한 구조적 언어 : HTML, CSS (계층이 있음)
#     웹의 작동 및 제어를 위한 프로그래밍 언어 :  Js

# %% [markdown]
# ### 셀렉터
#     용도 : html에서 내가 원하는 내용을 찾아내기 위해서
#     <span class="news" id="1234">비비고 왕교자</span>
#
#     단일 셀렉터
#
#     html.select('span')
#     tag : span
#     class(별명, 그룹명) : .news
#     id(고유값) : #1234

# %% [markdown]
# ### 복합 셀렉터
#     1. 조합 셀렉터
#     <span>1</span>
#     <span class="txt">2</span>
#     <li id="name">3</li>
#
#     태그 이름이 span이고 클래스 이름은 txt인 라인을 찾고 싶다. : span.txt
#     li 태그 중에서 id가 name 인 라인을 찾고 싶다. : li#name

# %% [markdown]
# ### 복합 셀렉터
#     2. 경로 셀렉터
#     <ul>
#         <li><span>이걸 찾으려면?</span></li>
#     </ul>
#     <span>이건 아님</span>
#
#     ul 태그안 li 태그 안 span 라인을 찾는다
#     ul > li > span 혹은 ul li span

# %% [markdown]
# #### 가져온 데이터에 접근을 하는 방식 자체는 판다스 색인처럼 결과값을 확인하며 진행하는 것이 가장 좋습니다.

# %% [markdown]
# ## 다음 로또 당첨 번호로 selecter 연습

# %%
import requests
from bs4 import BeautifulSoup

# %%
url2 = 'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=로또+번호'

# %%
response = requests.get(url2)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
#가져온 데이터를 html로 변환
html = BeautifulSoup(response.text, 'html.parser')

numbers = html.select('span.ball')
# Out:
# 접속성공

# %%
numbers
# Out:
# [<span class="ball bg_ball1">7</span>,
#  <span class="ball bg_ball2">11</span>,
#  <span class="ball bg_ball2">12</span>,
#  <span class="ball bg_ball4">31</span>,
#  <span class="ball bg_ball4">33</span>,
#  <span class="ball bg_ball4">38</span>,
#  <span class="ball txt_bonus"><span class="screen_out">보너스</span></span>,
#  <span class="ball bg_ball1">5</span>]

# %%
num_list=[]

# %%
for number in numbers:
    print(number.text)
# Out:
# 7
# 11
# 12
# 31
# 33
# 38
# 보너스
# 5

# %%
html.select('span.txt')
# Out:
# []

# %%
requests.codes.ok
# Out:
# 200

# %%
html.select('span')
# Out:
# [<span class="screen_out" id="daumServiceLogo">검색</span>,
#  <span class="ir_wa">한글입력기</span>,
#  <span class="ir_wa">검색</span>,
#  <span class="screen_out">선택된 항목</span>,
#  <span class="inner_tab"><span class="txt_tab">통합검색</span></span>,
#  <span class="txt_tab">통합검색</span>,
#  <span class="inner_tab"><span class="txt_tab">블로그</span></span>,
#  <span class="txt_tab">블로그</span>,
#  <span class="inner_tab"><span class="txt_tab">이미지</span></span>,
#  <span class="txt_tab">이미지</span>,
#  <span class="inner_tab"><span class="txt_tab">뉴스</span></span>,
#  <span class="txt_tab">뉴스</span>,
#  <span class="inner_tab">
#  <span class="txt_tab">백과사전</span>
#  <span class="ico_ksearch ico_outlink">새창</span>
#  </span>,
#  <span class="txt_tab">백과사전</span>,
#  <span class="ico_ksearch ico_outlink">새창</span>,
#  <span class="inner_tab"><span class="txt_tab">사이트</span></span>,
#  <span class="txt_tab">사이트</span>,
#  <span class="inner_tab"><span class="txt_tab">카페</span></span>,
# ...

# %%
html.select("span.ball")
# Out:
# [<span class="ball bg_ball1">7</span>,
#  <span class="ball bg_ball2">11</span>,
#  <span class="ball bg_ball2">12</span>,
#  <span class="ball bg_ball4">31</span>,
#  <span class="ball bg_ball4">33</span>,
#  <span class="ball bg_ball4">38</span>,
#  <span class="ball txt_bonus"><span class="screen_out">보너스</span></span>,
#  <span class="ball bg_ball1">5</span>]

# %%
response.status_code
#100번 대 : 우리 이런정보 내주는거야.
#200번 대 : 성공
#300번 대 : 우리 이사했는데 일루가
#400번 대 : 유저가 요청을 잘못 한 경우
#500번 대 : 서버문제

# %% [markdown]
# ## 네이터 키워드로 검색한 결과를 크롤링

# %%
key_word=input('키워드를 입력하세요')
url = 'https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query={key_word}'

response = requests.get(url)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
#가져온 데이터를 html로 변환
html = BeautifulSoup(response.text, 'html.parser')
data=html.select('a.sh_blog_title')

# for item in data:
#     print(item.attrs['title'],item.attrs['href'])
numbers = html.select('span.ball')
# Out:
# 키워드를 입력하세요해성막창
# 접속성공

# %%
url = 'https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=해성막창'

# %%
response = requests.get(url)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
#가져온 데이터를 html로 변환
html = BeautifulSoup(response.text, 'html.parser')

numbers = html.select('span.ball')
# Out:
# 접속성공

# %%
html.select('dd.txt_inline')[0]
# Out:
# <dd class="txt_inline">2020.04.29. </dd>

# %%
html.select('a.sh_blog_title')[0].text
# Out:
# '부산맛집 해성막창 센텀점 구이보다는 전골'

# %%
html.select('li')
# Out:
# [<li class="on _recentTab"><a href="javascript:;">최근검색어</a></li>,
#  <li class="_myTab"><a href="javascript:;">내 검색어</a></li>,
#  <li data-rank="@rank@"><a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a><a class="keyword" href="javascript:;">@txt@</a><em class="keyword_date">@date@.</em><a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a><span style="display:none">@in_txt@</span></li>,
#  <li data-rank="@rank@"><a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a><a class="keyword" href="javascript:;">@txt@</a></li>,
#  <li class="lnb0"><a class="tab on" href="?where=nexearch&amp;sm=tab_jum&amp;query=%ED%95%B4%EC%84%B1%EB%A7%89%EC%B0%BD" onclick="return goOtherCR(this,'a=tab*N.now&amp;r=1&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">통합검색</span></a></li>,
# ...

# %%
html.select('li a.data-area')
# Out:
# []

# %%
data[0].attrs['href']
# Out:
# 'https://blog.naver.com/whitenun?Redirect=Log&logNo=221935842302'

# %%
data=html.select('a.sh_blog_title')

# %%
for item in data:
    print(item.attrs['title'],item.attrs['href'])
# Out:
# 부산맛집 해성막창 센텀점 구이보다는 전골 https://blog.naver.com/whitenun?Redirect=Log&logNo=221935842302
# 부산 해성막창 먹으려고 해운대까지 갔네요 https://blog.naver.com/okyoky2000?Redirect=Log&logNo=221784992637
# 부산 해운대 해성막창 본점 두번째 방문 후기 ♥ https://blog.naver.com/jinmichu?Redirect=Log&logNo=221583343298
# 설명이 필요없는 부산 센텀 맛집 해성막창집 https://halbu1726.blog.me/221998847231
# [일광] 해운대 줄 서서 먹는 그 해성막창 곱창전골을 집에서!!!!!!!!!!! 일광 해성막창집 https://blog.naver.com/ssm8083?Redirect=Log&logNo=222017580849

# %%
for i in range(0,4):
    print(html.select('a.sh_blog_title')[i].text)
# Out:
# 부산맛집 해성막창 센텀점 구이보다는 전골
# 부산 해성막창 먹으려고 해운대까지 갔네요
# 부산 해운대 해성막창 본점 두번째 방문 후기 ♥
# 설명이 필요없는 부산 센텀 맛집 해성막창집

# %% [markdown]
# # 로또 번호 전체 회차

# %%
for item in range(1,10):
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# 네이버
for item in range(910,918):
    
    url = f'https://search.naver.com/search.naver?sm=tab_drt&where=nexearch&query={item}회로또'

    response = requests.get(url)


    #가져온 데이터를 html로 변환
    html = BeautifulSoup(response.text, 'html.parser')
    numbers=html.select('span.num')
    print(item,'회차')
    for number in numbers:
        
        print(number.text)
    print('')
# Out:
# 910 회차
# 1
# 11
# 17
# 27
# 35
# 39
# 31
#
# 911 회차
# 4
# 5
# 12
# 14
# 32
# 42
# 35
#
# 912 회차
# 5
# 8
# 18
# 21
# 22
# 38
# 10
#
# 913 회차
# 6
# 14
# 16
# 21
# 27
# 37
# 40
#
# 914 회차
# 16
# 19
# 24
# 33
# 42
# 44
# 27
#
# 915 회차
# 2
# 6
# 11
# 13
# 22
# 37
# 14
#
# 916 회차
# 6
# 21
# 22
# 32
# 35
# 36
# 17
#
# 917 회차
# 1
# 3
# 23
# 24
# 27
# 43
# 34

# %%
# 다음

for item in range(1,10):
    
    url = 'https://search.daum.net/search?w=tot&DA=LOT&rtmaxcoll=LOT&&q={item}회차%20로또'

    response = requests.get(url)


    #가져온 데이터를 html로 변환
    html = BeautifulSoup(response.text, 'html.parser')
    numbers=html.select('span.ball')
    for number in numbers:
        print(number.text)

# %% [markdown]
# ## 네이버 이미지, 동영상 크롤링

# %%
key_word=input('키워드를 입력하세요')
url = f'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={key_word}'

response = requests.get(url)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
#가져온 데이터를 html로 변환
html = BeautifulSoup(response.text, 'html.parser')

data=html.select('a.sh_blog_title')

numbers = html.select('span.ball')
# Out:
# 키워드를 입력하세요장원영
# 접속성공

# %%
total_img = html.select('img')

# %%
total_img
# Out:
# [<img alt="네이버" height="105" src="https://ssl.pstatic.net/sstatic/search/nlogo/20200706111431.png" usemap="#link_logo" width="330"/>,
#  <img alt="닫기" height="11" src="https://ssl.pstatic.net/sstatic/keypage/lifesrch/sports/img2010/bt_ly_close.gif" width="11"/>,
#  <img alt="지금까지 공개된 장원영 티저 사진들 | 카페" class="_img" data-height="1177" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fcafefiles.naver.net%2FMjAyMDA2MDZfMjM2%2FMDAxNTkxNDM1ODgxMTc0.uFwcEDsHPK9lbbppkfReaUMF4e70tZRuSqB3rAgZ63sg.QK_6cyxKJVNc9969Xlg8R-Hi5_38QYmH5Pqz2B-q1jkg.JPEG%2FexternalFile.jpg&amp;type=b400" data-width="960" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/>,
# ...

# %%
import urllib

# %%
urllib.request.urlretrieve(total_img[2].attrs['data-source'],'test.jpg')
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x27290d084e0>)

# %%
for item in range(2,10):
    urllib.request.urlretrieve(total_img[item].attrs['data-source'],f'test{item}.jpg')
    print(item,"성공")
# Out:
# 2 성공
# 3 성공
# 4 성공
# 5 성공
# 6 성공
# 7 성공
# 8 성공
# 9 성공

# %% [markdown]
# # 영상 가져오기

# %%
# 네이버

# %% [markdown]
# # 로또 번호

# %% [markdown]
# # 시간 벌어주는 함수들

# %%
import numpy as np
import time

# %%
np.random.seed(42)

# %%
# %%time
seed = a = np.random.randint(100)

np.random.seed(42)

print('코드 시작')
a= np.random.randint(5)
#######################################
print(a)
time.sleep(a)
print('코드 끝')
# Out:
# 코드 시작
# 3
# 코드 끝
# Wall time: 3 s

# %%
urllib.request.urlretrieve(URL,'')

# %% [markdown]
# ### 동적페이지 크롤링
#     최근에는 Js로 변경이 되며 일반적인 크롤링이 되지 않는 경우가 많음
#     동적페이지와 숨겨진 url을 가져오는 방법을 알아봅니다

# %% [markdown]
# ## 다음 주식 크롤링

# %%
import json


url = 'https://datalab.naver.com/shoppingInsight/getKeywordRank.naver?timeUnit=date&cid=50000001'

header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
    'referer': 'https://datalab.naver.com/'
}

response = requests.get(url, headers=header)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
data = json.loads(response.text)
print(data)
# Out:
# 접속성공
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-49bd96e4b516> in <module>
# ----> 1 df.ranks
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ranks'

# %%
data[0]['ranks'][0]
# Out:
# {'rank': 1, 'keyword': '파인드카푸어', 'linkId': '파인드카푸어'}

# %%
import json

url = 'http://finance.daum.net/api/quote/A005930/times?symbolCode=A005930&page=1&perPage=10&pagination=true'

header={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
    'referer': 'http://finance.daum.net/quotes/A005930'
}

response = requests.get(url, headers=header)

if reponse.status_code == requests.codes.ok:
    print("접속성공")
    
data = json.loads(response.text)
print(data)  
# #가져온 데이터를 html로 변환
# html = BeautifulSoup(response.text, 'html.parser')

# data=html.select('a.sh_blog_title')

# numbers = html.select('span.ball')
# Out:
# 접속성공
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
data['data']
# Out:
# [{'symbolCode': None,
#   'date': '2020-07-07 15:30:22',
#   'tradePrice': 53400.0,
#   'tradeTime': '15:30:22',
#   'change': 'FALL',
#   'changePrice': -1600.0,
#   'changeRate': -0.0290909091,
#   'prevClosingPrice': 55000.0,
#   'openingPrice': 53400.0,
#   'highPrice': 53400.0,
#   'lowPrice': 53400.0,
#   'accTradePrice': 1649497147500,
#   'accTradeVolume': 30328608,
#   'periodTradePrice': 92653645800,
#   'periodTradeVolume': 1735087,
#   'askTradePrice': None,
#   'bidTradePrice': None},
#  {'symbolCode': None,
#   'date': '2020-07-07 15:19:59',
#   'tradePrice': 53700.0,
#   'tradeTime': '15:19:59',
#   'change': 'FALL',
#   'changePrice': -1300.0,
#   'changeRate': -0.0236363636,
#   'prevClosingPrice': 55000.0,
#   'openingPrice': 53700.0,
#   'highPrice': 53700.0,
#   'lowPrice': 53600.0,
#   'accTradePrice': 1556843501700,
#   'accTradeVolume': 28593521,
#   'periodTradePrice': 3373523600,
#   'periodTradeVolume': 62898,
#   'askTradePrice': None,
# ...

# %%
df = pd.DataFrame(data['data'])

# %%
df
# Out:
#    accTradePrice  accTradeVolume askTradePrice bidTradePrice  ... prevClosingPrice  symbolCode  tradePrice tradeTime
# 0  1649497147500        30328608          None          None  ...          55000.0        None     53400.0  15:30:22
# 1  1556843501700        28593521          None          None  ...          55000.0        None     53700.0  15:19:59
# 2  1553469978100        28530623          None          None  ...          55000.0        None     53700.0  15:18:59
# 3  1548938111200        28446086          None          None  ...          55000.0        None     53600.0  15:17:59
# 4  1540981170100        28297632          None          None  ...          55000.0        None     53700.0  15:16:59
# 5  1530765605800        28106940          None          None  ...          55000.0        None     53600.0  15:15:59
# 6  1513213330900        27779451          None          None  ...          55000.0        None     53700.0  15:14:59
# ...

# %% [markdown]
# # 네이버 영화 클레멘타인 댓글 추출

# %%
import requests

#return requests.get(url).json()

# %% [markdown]
# import  json, requests
# from bs4 import BeautifulSoup
#
# url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=37886&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'
#
# for item in range(1,2):
#     header={
#         'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
#         'referer': f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=37886&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={item}'
#     }
#
#
#     response = requests.get(url, headers=header)
#
#     if response.status_code == requests.codes.ok:
#         print("접속성공")
#
#
#     html = BeautifulSoup(response.text, "html.parser")
#     collection = html.select('div.score_reple')
#     collection

# %%
collection
# Out:
# []

# %%
collection
# Out:
# [<div class="score_reple">
#  <p>
#  <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
#  <span id="_filtered_ment_0">
#
#
#
#  																이 영화를 보고 암이 나았습니다.
#
#
#
#  													</span>
#  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(7719905, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>maan****</span>
#  </a>
#  </em>
#  <em>2013.07.09 14:25</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','maan****', 'fXPuyh55WNkWbcpnosF1HKYfo9bor1bKkEaACzYzOLs=', '이 영화를 보고 암이 나았습니다. ', '7719905', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>, <div class="score_reple">
#  <p>
#  <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
#  <span id="_filtered_ment_1">
#
#
#
#  																이것은절대1점이아니다11점을주고싶은 내마음이다
#
#
#
#  													</span>
#  </p>
#  <dl>
#  <dt>
#  <em>
# ...

# %%
for item in range(0,10):
    print(item,'번째 댓글',collection[item].text)
# Out:
# 0 번째 댓글
#
#
#
#
#
#
# 																이 영화를 보고 암이 나았습니다.
#
#
#
#
#
#
#
#
#
# maan****
#
#
# 2013.07.09 14:25
#
#
# 신고
#
#
#
# 1 번째 댓글
#
#
#
#
#
#
# 																이것은절대1점이아니다11점을주고싶은 내마음이다
#
#
#
#
#
#
#
#
#
# joke****
#
#
# 2013.07.05 01:41
#
#
# 신고
#
#
#
# 2 번째 댓글
#
#
#
#
#
#
# 																모니터도 울고 외장하드도 울고 숨어있던 바이러스도 울었다
#
#
#
#
#
#
#
#
#
# 샤브레(dccm****)
#
#
# 2013.05.27 20:57
#
#
# 신고
#
#
#
# 3 번째 댓글
#
#
#
#
#
#
# 																당신이 이 영화를 보지 않았다면  아직 살아있을 이유 하나를 간직하고 있는 것이다.
#
#
#
#
#
#
#
#
#
# 그라운드(hank****)
#
#
# 2013.06.05 18:20
#
#
# 신고
#
#
#
# 4 번째 댓글
#
#
#
#
#
#
# 																영화계엔 BC와 AC가 있다. Before Clementain, After Clementain...
#
#
#
#
#
#
#
#
#
# Kyle(pool****)
#
#
# 2013.06.16 01:38
#
#
# 신고
#
#
#
# 5 번째 댓글
#
#
#
#
#
#
# 																남친 집에서 클레멘타인 DVD를 발견했고, 결혼을 결심했습니다.
#
#
#
#
#
#
#
#
#
# 미단스(mida****)
#
#
# 2014.02.18 17:00
#
#
# 신고
#
#
#
# 6 번째 댓글
#
#
#
#
#
#
# ...

# %%
#lis = score_result.findAll('li')
driver.get("https://movie.naver.com"+review_table)

data_group
# Out:
# []

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# # 클레멘타인 daum 영화

# %%
import  json, requests
from bs4 import BeautifulSoup

for item in range(1,10):
    url = f'https://movie.daum.net/moviedb/grade?movieId=38777&type=netizen&page={item}'

    header={
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
        'referer': 'https://movie.daum.net/moviedb/grade?movieId=38777'
    }

    response = requests.get(url, headers=header)

    if response.status_code == requests.codes.ok:
        print(item,"페이지")

    html = BeautifulSoup(response.text, "html.parser")
    collection = html.select('p.desc_review')
    
    
    for item in range(0,10):
        print(item+1,"번째 댓글", collection[item].text)
        print()
# Out:
# 1 페이지
# 1 번째 댓글
#                                             이 영화 이후 회자되는 다른 액션영화는 없을 것이다....
#
#
# 2 번째 댓글
#                                             최고 이루말할 수 없는 감동이다.아빠!일어나!
#
#
# 3 번째 댓글
#
#
# 4 번째 댓글
#                                             간만에 연차라 시갈흉 보이길래 편안하게 보려했는데 아침부터 눈시울 적시고.. 여턴 우리 사랑이가 다 했네..
#
#
# 5 번째 댓글
#                                             유나야 사랑해♡
#
#
# 6 번째 댓글
#                                             갓무비 그 자챔
#
#
# 7 번째 댓글
#  더 이상 물러설 곳이 없을 때 이 영화를 보고 싶다.져있더라도, 삶을 다른 관점에서 생각하게 하는 영화.이 평점을 남길 자격이 있으며, 다른 사람들의 평점을 진정으로 이해할 수 있다.
#
#
# 8 번째 댓글
# 100번을 봐도 처음 감동 그대로 입니다.                     보고 또 보고
#
#
# 9 번째 댓글
#                                             나도당했다^^
#
#
# 10 번째 댓글
#
#
# 2 페이지
# 1 번째 댓글
#  이시대 코로나를 극복할 단하나의 영화                       2004년도 영화를 2020년에도 리뷰가 올라오는 것만으로 평점은 대신할수있다!
#
#
# 2 번째 댓글
# "나 클레멘타인 보면서 클래!"                           아이가 말했습니다
#
#
# 3 번째 댓글
# 우울증 있는분들에게 신의 효능을 주는 댓글 잘 감상하시고 치유하시길...문해 글을 봅니다 클레멘타인을 보기전과 본 후로 나뉨
#
#
# ...

# %%
for item in range(0,5):
    print(collection[item].text)
    print()

# %%
review_list=[]

# %%
for item in collection:
    print(item.txt)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ## 네이버 데이터랩 인기검색어 크롤링
