# %% [markdown]
# # Pandas
#     데이터 과학자를 위해 테이블형태로 데이터를 다룰 수 있게 해주는 패키지 (python용 엑셀)
#     기존 데이터처리 라이브러리인 numpy 대신 주로 사용
#     일반인이 데이터분석을 접하기 쉽게 만들어준 결정적인 라이브러리
#     pandas만으로도 충분히 데이터 분석이 가능할 정도로 고수준의 함수들을 내장
#     앞으로 진행하는 데이터분석 과정에서 주로 사용하게 될 데이터구조

# %% [markdown]
# ### pandas 설치
#
#     콘솔창에서 실행 시
#     pip install pandas
#     conda install pandas
#
#     주피터 노트북으로 실행 시
#     !pip install pandas
#
#     아나콘다 환경으로 python 환경설정 시 기본적으로 설치가 되어있음

# %%
# pandas 설치
# !pip install pandas

# %%
# pandas import
import pandas as pd
# pd라는 닉네임은 많은 파이썬 유저들이 사용하고 있는 닉네임, 분석을 위한 필수는 아니지만 되도록이면 위와 같이 사용을 해줍시다.
pd.options.display.max_columns = 200 
# 불러들이는 데이터에 맞춰 모든 컬럼을 확인 가능하도록 옵션값을 주었습니다.
pd.options.display.max_info_columns =200 
# 그냥 실행 시키시고 지금 이해 못하셔도 좋습니다.

import numpy as np

# %% [markdown]
# ## 1. DataFrame
#     엑셀에 익숙한 사용자를 위해 제작 된 테이블형태의 데이터 구조
#     다양한 형태의 데이터를 받아 사용할 수 있으며 다양한 통계, 시각화 함수를 제공한다.
#
#     실제 데이터를 불러들이고 값을 확인 해 보며
#     기본적인 pandas 사용법을 익혀보도록 하겠습니다.

# %% [markdown]
# ### 데이터 불러오기
#     pandas는 다양한 데이터 파일 형태를 지원하며 주로 csv, xlsx, sql을 사용한다.
#
#     read_csv()
#     read_excel()
#     read_sql()

# %%
# %%time
# DataFrame 의 약자로서 형식적으로 df 변수명을 사용한다.
# pandas패키지의 read_csv() 함수를 사용하여 loan.csv 파일을 불러들여 데이터프레임을 만들고 df 이름의 변수로 저장
df = pd.read_csv('loan1.csv')
# Out:
# Wall time: 1.45 s

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\programdata\anaconda3\lib\site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('loan1.xlsx')

# %%
df
# Out:
#        Unnamed: 0  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0               0 NaN        NaN      10000        10000          10000.0
# 1               1 NaN        NaN       3500         3500           3500.0
# 2               2 NaN        NaN       5000         5000           5000.0
# 3               3 NaN        NaN      14000        14000          14000.0
# 4               4 NaN        NaN       5000         5000           5000.0
# 5               5 NaN        NaN      36000        36000          36000.0
# 6               6 NaN        NaN      20000        20000          20000.0
# 7               7 NaN        NaN       3200         3200           3200.0
# 8               8 NaN        NaN      14500        14500          14500.0
# 9               9 NaN        NaN      35000        35000          35000.0
# 10             10 NaN        NaN      40000        40000          40000.0
# 11             11 NaN        NaN      18000        18000          18000.0
# 12             12 NaN        NaN       6025         6025           6025.0
# 13             13 NaN        NaN      18000        18000          18000.0
# 14             14 NaN        NaN      10200        10200          10200.0
# 15             15 NaN        NaN      28000        28000          28000.0
# 16             16 NaN        NaN      23000        23000          23000.0
# 17             17 NaN        NaN      10000        10000          10000.0
# 18             18 NaN        NaN      12000        12000          12000.0
# 19             19 NaN        NaN       1500         1500           1500.0
# 20             20 NaN        NaN      14400        14400          14375.0
# 21             21 NaN        NaN      20000        20000          20000.0
# 22             22 NaN        NaN      40000        40000          40000.0
# 23             23 NaN        NaN      25000        25000          25000.0
# 24             24 NaN        NaN      28000        28000          27975.0
# 25             25 NaN        NaN      15500        15500          15500.0
# 26             26 NaN        NaN      10000        10000          10000.0
# 27             27 NaN        NaN      11200        11200          11175.0
# 28             28 NaN        NaN       7200         7200           7175.0
# 29             29 NaN        NaN      21600        21600          21600.0
# ...           ...  ..        ...        ...          ...              ...
# 49970       49970 NaN        NaN      12000        12000          12000.0
# 49971       49971 NaN        NaN      20000        20000          20000.0
# 49972       49972 NaN        NaN      18000        18000          18000.0
# 49973       49973 NaN        NaN       9600         9600           9600.0
# 49974       49974 NaN        NaN      24250        24250          24250.0
# 49975       49975 NaN        NaN      15000        15000          15000.0
# 49976       49976 NaN        NaN       3000         3000           3000.0
# 49977       49977 NaN        NaN      20000        20000          20000.0
# 49978       49978 NaN        NaN      15000        15000          14975.0
# 49979       49979 NaN        NaN      30000        30000          30000.0
# 49980       49980 NaN        NaN      12000        12000          12000.0
# 49981       49981 NaN        NaN      15000        15000          15000.0
# 49982       49982 NaN        NaN      30000        30000          30000.0
# 49983       49983 NaN        NaN       8000         8000           8000.0
# 49984       49984 NaN        NaN      25000        25000          25000.0
# 49985       49985 NaN        NaN      15000        15000          15000.0
# 49986       49986 NaN        NaN       6000         6000           6000.0
# 49987       49987 NaN        NaN      30000        30000          30000.0
# 49988       49988 NaN        NaN      10600        10600          10600.0
# 49989       49989 NaN        NaN      40000        40000          40000.0
# 49990       49990 NaN        NaN       7400         7400           7400.0
# 49991       49991 NaN        NaN      40000        40000          40000.0
# 49992       49992 NaN        NaN      15000        15000          15000.0
# 49993       49993 NaN        NaN      30000        30000          30000.0
# 49994       49994 NaN        NaN       8000         8000           8000.0
# 49995       49995 NaN        NaN      13000        13000          13000.0
# 49996       49996 NaN        NaN      12000        12000          12000.0
# 49997       49997 NaN        NaN      20000        20000          20000.0
# 49998       49998 NaN        NaN       7000         7000           7000.0
# 49999       49999 NaN        NaN       6000         6000           6000.0
#
#              term  int_rate  installment grade sub_grade  \
# 0       36 months      9.44       320.05     B        B1
# 1       36 months     10.42       113.63     B        B3
# 2       36 months     13.59       169.90     C        C2
# 3       36 months     10.91       457.75     B        B4
# 4       36 months     13.59       169.90     C        C2
# 5       60 months     14.08       839.16     C        C3
# 6       36 months      9.93       644.69     B        B2
# 7       36 months     10.91       104.63     B        B4
# 8       36 months     16.02       509.93     C        C5
# 9       36 months      6.08      1066.04     A        A2
# 10      60 months     16.02       973.15     C        C5
# 11      60 months     13.59       415.02     C        C2
# 12      36 months     17.09       215.08     D        D1
# 13      36 months      9.44       576.09     B        B1
# 14      36 months     11.99       338.74     B        B5
# 15      36 months     12.62       938.32     C        C1
# 16      60 months     19.03       597.02     D        D3
# 17      60 months     21.45       273.08     D        D5
# 18      60 months     12.62       270.71     C        C1
# 19      36 months     18.06        54.28     D        D2
# 20      36 months     20.00       535.16     D        D4
# 21      36 months      6.08       609.17     A        A2
# 22      36 months     10.42      1298.59     B        B3
# 23      60 months     12.62       563.98     C        C1
# 24      36 months     18.06      1013.12     D        D2
# 25      36 months     15.05       537.70     C        C4
# 26      36 months     19.03       366.72     D        D3
# 27      36 months     19.03       410.72     D        D3
# 28      36 months     13.59       244.65     C        C2
# 29      36 months      6.72       664.19     A        A3
# ...           ...       ...          ...   ...       ...
# 49970   36 months      7.97       375.88     A        A5
# 49971   60 months     24.85       585.27     E        E3
# 49972   36 months     10.91       588.54     B        B4
# 49973   36 months     14.08       328.48     C        C3
# 49974   60 months     21.45       662.20     D        D5
# 49975   36 months      7.97       469.84     A        A5
# 49976   36 months     12.62       100.54     C        C1
# 49977   60 months     17.09       498.02     D        D1
# 49978   36 months      5.32       451.73     A        A1
# 49979   60 months     12.62       676.78     C        C1
# 49980   36 months     13.59       407.75     C        C2
# 49981   60 months     15.05       357.25     C        C4
# 49982   36 months      7.97       939.68     A        A5
# 49983   36 months     10.42       259.72     B        B3
# 49984   36 months      9.93       805.86     B        B2
# 49985   60 months     17.09       373.52     D        D1
# 49986   36 months      7.35       186.23     A        A4
# 49987   60 months      9.44       629.18     B        B1
# 49988   36 months     16.02       372.77     C        C5
# 49989   36 months      7.97      1252.91     A        A5
# 49990   36 months      6.72       227.55     A        A3
# 49991   60 months      9.44       838.91     B        B1
# 49992   36 months     19.03       550.07     D        D3
# 49993   36 months     13.59      1019.37     C        C2
# 49994   36 months     15.05       277.52     C        C4
# 49995   60 months     18.06       330.54     D        D2
# 49996   60 months     13.59       276.68     C        C2
# 49997   60 months     15.05       476.33     C        C4
# 49998   36 months      7.35       217.27     A        A4
# 49999   36 months     13.59       203.88     C        C2
#
#                                    emp_title emp_length home_ownership  \
# 0                                   mechanic    6 years       MORTGAGE
# 1                                        NaN        NaN            OWN
# 2                               Truck driver  10+ years            OWN
# 3                     Confidential Secretary    2 years           RENT
# 4                            General Manager   < 1 year           RENT
# 5                                    NDT III  10+ years           RENT
# 6                Supervisory program analyst  10+ years       MORTGAGE
# 7                Commercial Property Manager   < 1 year       MORTGAGE
# 8                       Equipment technician   < 1 year       MORTGAGE
# 9                                        NaN        NaN            OWN
# 10             IT Manager - Business Process  10+ years            OWN
# 11                 Strategic Account Manager     1 year       MORTGAGE
# 12                           Account Manager    5 years           RENT
# 13                           sales associate    2 years            OWN
# 14                          Machine operator    4 years           RENT
# 15                            Vice President    3 years           RENT
# 16                      Installation Manager  10+ years       MORTGAGE
# 17                             Senior Agent     2 years           RENT
# 18                         commercial sales   10+ years            OWN
# 19                                     sales  10+ years           RENT
# 20                Assistant General Manager     4 years           RENT
# 21                   Control System Designer    2 years            OWN
# 22                                   Teacher  10+ years       MORTGAGE
# 23                                Consultant    4 years           RENT
# 24                            Office manager    5 years           RENT
# 25                         Probation Officer  10+ years           RENT
# 26                            Showroom Sales     1 year       MORTGAGE
# 27                                    Server    5 years           RENT
# 28                                       EMT    5 years       MORTGAGE
# 29                            Policy Analyst   < 1 year           RENT
# ...                                      ...        ...            ...
# 49970                                    ASA    2 years           RENT
# 49971                    Stationary Engineer  10+ years       MORTGAGE
# 49972                              PRESIDENT   < 1 year       MORTGAGE
# 49973                          ADMINISTRATOR    4 years       MORTGAGE
# 49974                    Executive Assistant    2 years           RENT
# 49975                        General manager  10+ years       MORTGAGE
# 49976                                 Nanny    < 1 year           RENT
# 49977               Customer Service Manager    4 years       MORTGAGE
# 49978                     restaurant manager    5 years           RENT
# 49979                                  Owner    2 years            OWN
# 49980                                    NaN        NaN       MORTGAGE
# 49981                                    NaN        NaN           RENT
# 49982                            Captain/EMT  10+ years       MORTGAGE
# 49983                                     PO  10+ years            OWN
# 49984                                    NaN        NaN            OWN
# 49985                                janitor   < 1 year       MORTGAGE
# 49986                  Physical Therapy Aide    4 years            OWN
# 49987                                teacher   < 1 year       MORTGAGE
# 49988  Senior VP & Chief Information Officer  10+ years       MORTGAGE
# 49989                         Title searcher    7 years           RENT
# 49990                           Radiographer  10+ years       MORTGAGE
# 49991              Aviation Maintenance Tech  10+ years       MORTGAGE
# 49992                          Administrator   < 1 year            OWN
# 49993                               Attorney  10+ years       MORTGAGE
# 49994                             Bartender     9 years           RENT
# 49995                    Clinical Supervisor  10+ years           RENT
# 49996                             consultant    2 years           RENT
# 49997                      Controls Engineer    2 years       MORTGAGE
# 49998                           Hair Stylist   < 1 year           RENT
# 49999                         Store manager      1 year           RENT
#
#        annual_inc verification_status   issue_d         loan_status  \
# 0         80000.0        Not Verified  Dec-2017             Current
# 1         90000.0        Not Verified  Dec-2017             Current
# 2        168000.0        Not Verified  Dec-2017             Current
# 3         39000.0     Source Verified  Dec-2017             Current
# 4         55000.0        Not Verified  Dec-2017             Current
# 5         74000.0        Not Verified  Dec-2017             Current
# 6        140000.0        Not Verified  Dec-2017             Current
# 7         48000.0        Not Verified  Dec-2017             Current
# 8         38000.0        Not Verified  Dec-2017             Current
# 9         76000.0            Verified  Dec-2017             Current
# 10       140000.0            Verified  Dec-2017             Current
# 11       325000.0     Source Verified  Dec-2017     In Grace Period
# 12        62000.0        Not Verified  Dec-2017             Current
# 13        22000.0     Source Verified  Dec-2017          Fully Paid
# 14        35000.0     Source Verified  Dec-2017             Current
# 15       270000.0     Source Verified  Dec-2017          Fully Paid
# 16        75000.0     Source Verified  Dec-2017             Current
# 17        26685.0            Verified  Dec-2017  Late (31-120 days)
# 18        40000.0     Source Verified  Dec-2017             Current
# 19        75000.0     Source Verified  Dec-2017             Current
# 20        38500.0            Verified  Dec-2017         Charged Off
# 21       149000.0            Verified  Dec-2017             Current
# 22        54000.0            Verified  Dec-2017             Current
# 23        99000.0            Verified  Dec-2017          Fully Paid
# 24        41000.0            Verified  Dec-2017         Charged Off
# 25        93400.0     Source Verified  Dec-2017             Current
# 26        54000.0        Not Verified  Dec-2017             Current
# 27        40000.0     Source Verified  Dec-2017             Current
# 28        52000.0     Source Verified  Dec-2017          Fully Paid
# 29        44000.0        Not Verified  Dec-2017             Current
# ...           ...                 ...       ...                 ...
# 49970     70000.0     Source Verified  Nov-2017          Fully Paid
# 49971     70000.0        Not Verified  Nov-2017             Current
# 49972     80000.0        Not Verified  Nov-2017          Fully Paid
# 49973    126109.0        Not Verified  Nov-2017          Fully Paid
# 49974     80000.0        Not Verified  Nov-2017             Current
# 49975     79040.0        Not Verified  Nov-2017             Current
# 49976     36000.0        Not Verified  Nov-2017             Current
# 49977    110000.0     Source Verified  Nov-2017             Current
# 49978     70000.0        Not Verified  Nov-2017             Current
# 49979    127000.0     Source Verified  Nov-2017             Current
# 49980     65000.0            Verified  Nov-2017          Fully Paid
# 49981     65000.0     Source Verified  Nov-2017             Current
# 49982     67000.0     Source Verified  Nov-2017             Current
# 49983    200000.0     Source Verified  Nov-2017             Current
# 49984     48000.0            Verified  Nov-2017             Current
# 49985     71900.0     Source Verified  Nov-2017             Current
# 49986     27800.0        Not Verified  Nov-2017             Current
# 49987     35000.0     Source Verified  Nov-2017         Charged Off
# 49988    165000.0     Source Verified  Nov-2017             Current
# 49989     80000.0        Not Verified  Nov-2017          Fully Paid
# 49990     43000.0        Not Verified  Nov-2017             Current
# 49991    100000.0            Verified  Nov-2017             Current
# 49992     38000.0        Not Verified  Nov-2017         Charged Off
# 49993    115000.0            Verified  Nov-2017             Current
# 49994     55000.0     Source Verified  Nov-2017             Current
# 49995     60000.0        Not Verified  Nov-2017             Current
# 49996     90000.0        Not Verified  Nov-2017          Fully Paid
# 49997    105000.0        Not Verified  Nov-2017             Current
# 49998     30000.0            Verified  Nov-2017             Current
# 49999     50000.0        Not Verified  Nov-2017          Fully Paid
#
#       pymnt_plan  url  desc             purpose                    title  \
# 0              n  NaN   NaN         credit_card  Credit card refinancing
# 1              n  NaN   NaN               other                    Other
# 2              n  NaN   NaN               other                    Other
# 3              n  NaN   NaN         credit_card  Credit card refinancing
# 4              n  NaN   NaN  debt_consolidation       Debt consolidation
# 5              n  NaN   NaN  debt_consolidation       Debt consolidation
# 6              n  NaN   NaN  debt_consolidation       Debt consolidation
# 7              n  NaN   NaN               other                    Other
# 8              n  NaN   NaN  debt_consolidation       Debt consolidation
# 9              n  NaN   NaN         credit_card  Credit card refinancing
# 10             n  NaN   NaN  debt_consolidation       Debt consolidation
# 11             n  NaN   NaN  debt_consolidation       Debt consolidation
# 12             n  NaN   NaN  debt_consolidation       Debt consolidation
# 13             n  NaN   NaN  debt_consolidation       Debt consolidation
# 14             n  NaN   NaN  debt_consolidation       Debt consolidation
# 15             n  NaN   NaN         credit_card  Credit card refinancing
# 16             n  NaN   NaN  debt_consolidation       Debt consolidation
# 17             n  NaN   NaN              moving    Moving and relocation
# 18             n  NaN   NaN  debt_consolidation       Debt consolidation
# 19             n  NaN   NaN         credit_card  Credit card refinancing
# 20             n  NaN   NaN  debt_consolidation       Debt consolidation
# 21             n  NaN   NaN               other                    Other
# 22             n  NaN   NaN  debt_consolidation       Debt consolidation
# 23             n  NaN   NaN  debt_consolidation       Debt consolidation
# 24             n  NaN   NaN  debt_consolidation       Debt consolidation
# 25             n  NaN   NaN  debt_consolidation       Debt consolidation
# 26             n  NaN   NaN    home_improvement         Home improvement
# 27             n  NaN   NaN  debt_consolidation       Debt consolidation
# 28             n  NaN   NaN  debt_consolidation       Debt consolidation
# 29             n  NaN   NaN  debt_consolidation       Debt consolidation
# ...          ...  ...   ...                 ...                      ...
# 49970          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49971          n  NaN   NaN    home_improvement         Home improvement
# 49972          n  NaN   NaN         credit_card  Credit card refinancing
# 49973          n  NaN   NaN               other                    Other
# 49974          n  NaN   NaN         credit_card  Credit card refinancing
# 49975          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49976          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49977          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49978          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49979          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49980          n  NaN   NaN    home_improvement         Home improvement
# 49981          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49982          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49983          n  NaN   NaN      major_purchase           Major purchase
# 49984          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49985          n  NaN   NaN    home_improvement         Home improvement
# 49986          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49987          n  NaN   NaN    home_improvement         Home improvement
# 49988          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49989          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49990          n  NaN   NaN         credit_card  Credit card refinancing
# 49991          n  NaN   NaN         credit_card  Credit card refinancing
# 49992          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49993          n  NaN   NaN         credit_card  Credit card refinancing
# 49994          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49995          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49996          n  NaN   NaN         credit_card  Credit card refinancing
# 49997          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49998          n  NaN   NaN         credit_card  Credit card refinancing
# 49999          n  NaN   NaN         credit_card  Credit card refinancing
#
#       zip_code addr_state    dti  delinq_2yrs earliest_cr_line  \
# 0        762xx         TX  14.82            0         Jul-2007
# 1        295xx         SC  28.51            0         Jun-2002
# 2        788xx         TX  11.62            0         Aug-2002
# 3        125xx         NY  22.88            0         Apr-2003
# 4        672xx         KS  12.18            0         Jun-1999
# 5        920xx         CA  21.46            0         Apr-2001
# 6        750xx         TX   7.76            2         May-1988
# 7        936xx         CA  16.66            0         Mar-2006
# 8        765xx         TX  14.28            0         Oct-2008
# 9        388xx         MS  34.28            0         Aug-1994
# 10       292xx         SC  31.79            1         Aug-1999
# 11       027xx         MA  14.12            0         Nov-2003
# 12       010xx         MA  14.65            0         Aug-2004
# 13       439xx         OH  31.21            0         Feb-2008
# 14       635xx         MO  15.26            0         Dec-2008
# 15       945xx         CA   8.25            0         Mar-1996
# 16       585xx         ND  27.64            0         Dec-2002
# 17       331xx         FL  23.12            0         Sep-2011
# 18       394xx         MS   7.74            0         Nov-1986
# 19       197xx         DE   9.50            0         Mar-2004
# 20       799xx         TX  30.94            0         Apr-2007
# 21       770xx         TX  13.31            0         Jul-1999
# 22       630xx         MO  47.44            0         Nov-1990
# 23       301xx         GA  14.61            0         Mar-2003
# 24       274xx         NC  21.36            0         Dec-2013
# 25       791xx         TX  17.20            2         Nov-2002
# 26       461xx         IN  27.16            0         Jul-2005
# 27       912xx         CA  26.92            1         Feb-2006
# 28       935xx         CA  26.10            0         Sep-2004
# 29       973xx         OR  17.21            0         Sep-2008
# ...        ...        ...    ...          ...              ...
# 49970    212xx         MD  25.17            0         Aug-2007
# 49971    212xx         MD  14.25            0         Sep-2007
# 49972    857xx         AZ  20.13            0         Aug-2000
# 49973    630xx         MO  25.56            0         Oct-1994
# 49974    208xx         MD  21.32            0         Apr-2007
# 49975    331xx         FL  15.75            0         Nov-2004
# 49976    114xx         NY   3.20            0         May-2009
# 49977    352xx         AL   6.87            0         Aug-2004
# 49978    940xx         CA   8.38            0         Apr-2005
# 49979    714xx         LA   8.02            0         Nov-2011
# 49980    985xx         WA  28.62            0         Apr-2003
# 49981    280xx         NC  25.50            0         Oct-1998
# 49982    335xx         FL  21.60            0         Apr-2003
# 49983    109xx         NH   9.09            4         Dec-1997
# 49984    799xx         TX  12.48            1         Nov-1992
# 49985    453xx         OH   0.00            0         Jul-2003
# 49986    483xx         MI   8.03            0         Feb-2011
# 49987    065xx         CT   0.45            0         Jan-2003
# 49988    020xx         MA  37.58            0         Nov-1990
# 49989    112xx         NY  13.08            0         May-2004
# 49981         0.0                      0.0     Feb-2019           357.25
# 49982         0.0                      0.0     Feb-2019           939.68
# 49983         0.0                      0.0     Feb-2019           259.72
# 49984         0.0                      0.0     Feb-2019          1130.68
# 49985         0.0                      0.0     Feb-2019           373.52
# 49986         0.0                      0.0     Feb-2019           186.23
# 49987         0.0                      0.0     Sep-2018           698.01
# 49988         0.0                      0.0     Feb-2019           372.77
# 49989         0.0                      0.0     Aug-2018         32130.26
# 49990         0.0                      0.0     Feb-2019           227.55
# 49991         0.0                      0.0     Feb-2019           838.91
# 49992        50.0                      9.0     Jan-2019            50.00
# ...
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# 5                                 NaN                           NaN
# 6                                 NaN                           NaN
# 7                                 NaN                           NaN
# 8                                 NaN                           NaN
# 9                                 NaN                           NaN
# 10                                NaN                           NaN
# 11                                NaN                           NaN
# 12                                NaN                           NaN
# 13                                NaN                           NaN
# 14                                NaN                           NaN
# 15                                NaN                           NaN
# 16                                NaN                           NaN
# 17                                NaN                           NaN
# 18                                NaN                           NaN
# 19                                NaN                           NaN
# 20                                NaN                           NaN
# 21                                NaN                           NaN
# 22                                NaN                           NaN
# 23                                NaN                           NaN
# 24                                NaN                           NaN
# 25                                NaN                           NaN
# 26                                NaN                           NaN
# 27                                NaN                           NaN
# 28                                NaN                           NaN
# 29                                NaN                           NaN
# ...                               ...                           ...
# 49970                             NaN                           NaN
# 49971                             NaN                           NaN
# 49972                             NaN                           NaN
# 49973                             NaN                           NaN
# 49974                             NaN                           NaN
# 49975                             NaN                           NaN
# 49976                             NaN                           NaN
# 49977                             NaN                           NaN
# 49978                             NaN                           NaN
# 49979                             NaN                           NaN
# 49980                             NaN                           NaN
# 49981                             NaN                           NaN
# 49982                             NaN                           NaN
# 49983                             NaN                           NaN
# 49984                             NaN                           NaN
# 49985                             NaN                           NaN
# 49986                             NaN                           NaN
# 49987                             NaN                           NaN
# 49988                             NaN                           NaN
# 49989                             NaN                           NaN
# 49990                             NaN                           NaN
# 49991                             NaN                           NaN
# 49992                             NaN                           NaN
# 49993                             NaN                           NaN
# 49994                             NaN                           NaN
# 49995                             NaN                           NaN
# 49996                             NaN                           NaN
# 49997                             NaN                           NaN
# 49998                             NaN                           NaN
# 49999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                    N                       NaN
# 1                    Cash                    N                       NaN
# 2                    Cash                    N                       NaN
# 3                    Cash                    N                       NaN
# 4                    Cash                    N                       NaN
# 5                    Cash                    N                       NaN
# 6                    Cash                    N                       NaN
# 7                    Cash                    N                       NaN
# 8                    Cash                    N                       NaN
# 9               DirectPay                    N                       NaN
# 10                   Cash                    N                       NaN
# 11                   Cash                    N                       NaN
# 12                   Cash                    N                       NaN
# 13                   Cash                    N                       NaN
# 14                   Cash                    N                       NaN
# 15                   Cash                    N                       NaN
# 16                   Cash                    N                       NaN
# 17                   Cash                    N                       NaN
# 18                   Cash                    N                       NaN
# 19                   Cash                    N                       NaN
# 20                   Cash                    N                       NaN
# 21                   Cash                    N                       NaN
# 22                   Cash                    N                       NaN
# 23                   Cash                    N                       NaN
# 24                   Cash                    N                       NaN
# 25                   Cash                    N                       NaN
# 26                   Cash                    N                       NaN
# 27                   Cash                    N                       NaN
# 28                   Cash                    N                       NaN
# 29                   Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 49970                Cash                    N                       NaN
# 49971                Cash                    N                       NaN
# 49972                Cash                    N                       NaN
# 49973                Cash                    N                       NaN
# 49974                Cash                    N                       NaN
# 49975                Cash                    N                       NaN
# 49976                Cash                    N                       NaN
# 49977                Cash                    N                       NaN
# 49978                Cash                    N                       NaN
# 49979                Cash                    N                       NaN
# 49980                Cash                    N                       NaN
# 49981                Cash                    N                       NaN
# 49982                Cash                    N                       NaN
# 49983                Cash                    N                       NaN
# 49984                Cash                    N                       NaN
# 49985                Cash                    N                       NaN
# 49986                Cash                    N                       NaN
# 49987                Cash                    N                       NaN
# 49988                Cash                    N                       NaN
# 49989                Cash                    N                       NaN
# 49990           DirectPay                    N                       NaN
# 49991                Cash                    N                       NaN
# 49992                Cash                    Y                  Nov-2018
# 49993                Cash                    N                       NaN
# 49994                Cash                    N                       NaN
# 49995                Cash                    N                       NaN
# 49996                Cash                    N                       NaN
# 49997                Cash                    N                       NaN
# 49998                Cash                    N                       NaN
# 49999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 0                   NaN             NaN                NaN
# 1                   NaN             NaN                NaN
# 2                   NaN             NaN                NaN
# 3                   NaN             NaN                NaN
# 4                   NaN             NaN                NaN
# 5                   NaN             NaN                NaN
# 6                   NaN             NaN                NaN
# 7                   NaN             NaN                NaN
# 8                   NaN             NaN                NaN
# 9                   NaN             NaN                NaN
# 10                  NaN             NaN                NaN
# 11                  NaN             NaN                NaN
# 12                  NaN             NaN                NaN
# 13                  NaN             NaN                NaN
# 14                  NaN             NaN                NaN
# 15                  NaN             NaN                NaN
# 16                  NaN             NaN                NaN
# 17                  NaN             NaN                NaN
# 18                  NaN             NaN                NaN
# 19                  NaN             NaN                NaN
# 20                  NaN             NaN                NaN
# 21                  NaN             NaN                NaN
# 22                  NaN             NaN                NaN
# 23                  NaN             NaN                NaN
# 24                  NaN             NaN                NaN
# 25                  NaN             NaN                NaN
# 26                  NaN             NaN                NaN
# 27                  NaN             NaN                NaN
# 28                  NaN             NaN                NaN
# 29                  NaN             NaN                NaN
# ...                 ...             ...                ...
# 49970               NaN             NaN                NaN
# 49971               NaN             NaN                NaN
# 49972               NaN             NaN                NaN
# 49973               NaN             NaN                NaN
# 49974               NaN             NaN                NaN
# 49975               NaN             NaN                NaN
# 49976               NaN             NaN                NaN
# 49977               NaN             NaN                NaN
# 49978               NaN             NaN                NaN
# 49979               NaN             NaN                NaN
# 49980               NaN             NaN                NaN
# 49981               NaN             NaN                NaN
# 49982               NaN             NaN                NaN
# 49983               NaN             NaN                NaN
# 49984               NaN             NaN                NaN
# 49985               NaN             NaN                NaN
# 49986               NaN             NaN                NaN
# 49987               NaN             NaN                NaN
# 49988               NaN             NaN                NaN
# 49989               NaN             NaN                NaN
# 49990               NaN             NaN                NaN
# 49991               NaN             NaN                NaN
# 49992            ACTIVE        Nov-2018             7578.0
# 49993               NaN             NaN                NaN
# 49994               NaN             NaN                NaN
# 49995               NaN             NaN                NaN
# 49996               NaN             NaN                NaN
# 49997               NaN             NaN                NaN
# 49998               NaN             NaN                NaN
# 49999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# 5                        NaN              NaN
# 6                        NaN              NaN
# 7                        NaN              NaN
# 8                        NaN              NaN
# 9                        NaN              NaN
# 10                       NaN              NaN
# 11                       NaN              NaN
# 12                       NaN              NaN
# 13                       NaN              NaN
# 14                       NaN              NaN
# 15                       NaN              NaN
# 16                       NaN              NaN
# 17                       NaN              NaN
# 18                       NaN              NaN
# 19                       NaN              NaN
# 20                       NaN              NaN
# 21                       NaN              NaN
# 22                       NaN              NaN
# 23                       NaN              NaN
# 24                       NaN              NaN
# 25                       NaN              NaN
# 26                       NaN              NaN
# 27                       NaN              NaN
# 28                       NaN              NaN
# 29                       NaN              NaN
# ...                      ...              ...
# 49970                    NaN              NaN
# 49971                    NaN              NaN
# 49972                    NaN              NaN
# 49973                    NaN              NaN
# 49974                    NaN              NaN
# 49975                    NaN              NaN
# 49976                    NaN              NaN
# 49977                    NaN              NaN
# 49978                    NaN              NaN
# 49979                    NaN              NaN
# 49980                    NaN              NaN
# 49981                    NaN              NaN
# 49982                    NaN              NaN
# 49983                    NaN              NaN
# 49984                    NaN              NaN
# 49985                    NaN              NaN
# 49986                    NaN              NaN
# 49987                    NaN              NaN
# 49988                    NaN              NaN
# 49989                    NaN              NaN
# 49990                    NaN              NaN
# 49991                    NaN              NaN
# 49992                   60.0             18.0
# 49993                    NaN              NaN
# 49994                    NaN              NaN
# 49995                    NaN              NaN
# 49996                    NaN              NaN
# 49997                    NaN              NaN
# 49998                    NaN              NaN
# 49999                    NaN              NaN
#
# [50000 rows x 146 columns]

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KIMMINKYU\\Desktop\\day1'

# %%
# !pip install xlrd

# df = pd.read_excel('‪./loan1.xlsx')
# Out:
# Requirement already satisfied: xlrd in c:\programdata\anaconda3\lib\site-packages (1.2.0)

# %%
# %%time
# 만약 모듈을 찾을 수 없는 오류가 발생한다면 추가 모듈 설치
# !pip install xlrd

df = pd.read_excel('‪loan1.xlsx')

# %%
# 데이터프레임 확인
df

# %%
# 참고! 실습은 하지 않습니다만 쿼리를 사용하여 데이터베이스로부터 데이터프레임을 만드는 것도 가능합니다.
# 데이터베이스로 부터 자료 읽기

# 필요한 모듈 추가 설치 - 각 데이터베이스 별로 다릅니다.
# !pip install pymysql

# sql 모듈 로드하기
# import pymysql
# mysql, mariadb, sqlite, postgresql, ms-sql, oracle, mongodb

# 접속하기
# 접속방법 또한 DB 종류에 따라 다릅니다.
# con = pymysql.connect(host='db서버주소', port=3306, user='id', passwd='pwd', db='dbname')

# query 만들기
# query = 'select * from samples'

# 자료 불러오기
# data = pd.read_sql(query, con=con)

# %% [markdown]
# ### 데이터 저장하기
#     불러들인 혹은 작업을 마친 데이터프레임을 다양한 파일형태로 저장이 가능합니다.
#
#     to_csv()
#     to_excel()
#     to_sql()

# %%
# %%time
df = pd.to_csv('loan1_test.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
# %%time
df.to_excel('loan1_test.xlsx')
# Out:
# Wall time: 2min 19s

# %%
df
# Out:
#        Unnamed: 0  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0               0 NaN        NaN      10000        10000          10000.0
# 1               1 NaN        NaN       3500         3500           3500.0
# 2               2 NaN        NaN       5000         5000           5000.0
# 3               3 NaN        NaN      14000        14000          14000.0
# 4               4 NaN        NaN       5000         5000           5000.0
# 5               5 NaN        NaN      36000        36000          36000.0
# 6               6 NaN        NaN      20000        20000          20000.0
# 7               7 NaN        NaN       3200         3200           3200.0
# 8               8 NaN        NaN      14500        14500          14500.0
# 9               9 NaN        NaN      35000        35000          35000.0
# 10             10 NaN        NaN      40000        40000          40000.0
# 11             11 NaN        NaN      18000        18000          18000.0
# 12             12 NaN        NaN       6025         6025           6025.0
# 13             13 NaN        NaN      18000        18000          18000.0
# 14             14 NaN        NaN      10200        10200          10200.0
# 15             15 NaN        NaN      28000        28000          28000.0
# 16             16 NaN        NaN      23000        23000          23000.0
# 17             17 NaN        NaN      10000        10000          10000.0
# 18             18 NaN        NaN      12000        12000          12000.0
# 19             19 NaN        NaN       1500         1500           1500.0
# 20             20 NaN        NaN      14400        14400          14375.0
# 21             21 NaN        NaN      20000        20000          20000.0
# 22             22 NaN        NaN      40000        40000          40000.0
# 23             23 NaN        NaN      25000        25000          25000.0
# 24             24 NaN        NaN      28000        28000          27975.0
# 25             25 NaN        NaN      15500        15500          15500.0
# 26             26 NaN        NaN      10000        10000          10000.0
# 27             27 NaN        NaN      11200        11200          11175.0
# 28             28 NaN        NaN       7200         7200           7175.0
# 29             29 NaN        NaN      21600        21600          21600.0
# ...           ...  ..        ...        ...          ...              ...
# 49970       49970 NaN        NaN      12000        12000          12000.0
# 49971       49971 NaN        NaN      20000        20000          20000.0
# 49972       49972 NaN        NaN      18000        18000          18000.0
# 49973       49973 NaN        NaN       9600         9600           9600.0
# 49974       49974 NaN        NaN      24250        24250          24250.0
# 49975       49975 NaN        NaN      15000        15000          15000.0
# 49976       49976 NaN        NaN       3000         3000           3000.0
# 49977       49977 NaN        NaN      20000        20000          20000.0
# 49978       49978 NaN        NaN      15000        15000          14975.0
# 49979       49979 NaN        NaN      30000        30000          30000.0
# 49980       49980 NaN        NaN      12000        12000          12000.0
# 49981       49981 NaN        NaN      15000        15000          15000.0
# 49982       49982 NaN        NaN      30000        30000          30000.0
# 49983       49983 NaN        NaN       8000         8000           8000.0
# 49984       49984 NaN        NaN      25000        25000          25000.0
# 49985       49985 NaN        NaN      15000        15000          15000.0
# 49986       49986 NaN        NaN       6000         6000           6000.0
# 49987       49987 NaN        NaN      30000        30000          30000.0
# 49988       49988 NaN        NaN      10600        10600          10600.0
# 49989       49989 NaN        NaN      40000        40000          40000.0
# 49990       49990 NaN        NaN       7400         7400           7400.0
# 49991       49991 NaN        NaN      40000        40000          40000.0
# 49992       49992 NaN        NaN      15000        15000          15000.0
# 49993       49993 NaN        NaN      30000        30000          30000.0
# 49994       49994 NaN        NaN       8000         8000           8000.0
# 49995       49995 NaN        NaN      13000        13000          13000.0
# 49996       49996 NaN        NaN      12000        12000          12000.0
# 49997       49997 NaN        NaN      20000        20000          20000.0
# 49998       49998 NaN        NaN       7000         7000           7000.0
# 49999       49999 NaN        NaN       6000         6000           6000.0
#
#              term  int_rate  installment grade sub_grade  \
# 0       36 months      9.44       320.05     B        B1
# 1       36 months     10.42       113.63     B        B3
# 2       36 months     13.59       169.90     C        C2
# 3       36 months     10.91       457.75     B        B4
# 4       36 months     13.59       169.90     C        C2
# 5       60 months     14.08       839.16     C        C3
# 6       36 months      9.93       644.69     B        B2
# 7       36 months     10.91       104.63     B        B4
# 8       36 months     16.02       509.93     C        C5
# 9       36 months      6.08      1066.04     A        A2
# 10      60 months     16.02       973.15     C        C5
# 11      60 months     13.59       415.02     C        C2
# 12      36 months     17.09       215.08     D        D1
# 13      36 months      9.44       576.09     B        B1
# 14      36 months     11.99       338.74     B        B5
# 15      36 months     12.62       938.32     C        C1
# 16      60 months     19.03       597.02     D        D3
# 17      60 months     21.45       273.08     D        D5
# 18      60 months     12.62       270.71     C        C1
# 19      36 months     18.06        54.28     D        D2
# 20      36 months     20.00       535.16     D        D4
# 21      36 months      6.08       609.17     A        A2
# 22      36 months     10.42      1298.59     B        B3
# 23      60 months     12.62       563.98     C        C1
# 24      36 months     18.06      1013.12     D        D2
# 25      36 months     15.05       537.70     C        C4
# 26      36 months     19.03       366.72     D        D3
# 27      36 months     19.03       410.72     D        D3
# 28      36 months     13.59       244.65     C        C2
# 29      36 months      6.72       664.19     A        A3
# ...           ...       ...          ...   ...       ...
# 49970   36 months      7.97       375.88     A        A5
# 49971   60 months     24.85       585.27     E        E3
# 49972   36 months     10.91       588.54     B        B4
# 49973   36 months     14.08       328.48     C        C3
# 49974   60 months     21.45       662.20     D        D5
# 49975   36 months      7.97       469.84     A        A5
# 49976   36 months     12.62       100.54     C        C1
# 49977   60 months     17.09       498.02     D        D1
# 49978   36 months      5.32       451.73     A        A1
# 49979   60 months     12.62       676.78     C        C1
# 49980   36 months     13.59       407.75     C        C2
# 49981   60 months     15.05       357.25     C        C4
# 49982   36 months      7.97       939.68     A        A5
# 49983   36 months     10.42       259.72     B        B3
# 49984   36 months      9.93       805.86     B        B2
# 49985   60 months     17.09       373.52     D        D1
# 49986   36 months      7.35       186.23     A        A4
# 49987   60 months      9.44       629.18     B        B1
# 49988   36 months     16.02       372.77     C        C5
# 49989   36 months      7.97      1252.91     A        A5
# 49990   36 months      6.72       227.55     A        A3
# 49991   60 months      9.44       838.91     B        B1
# 49992   36 months     19.03       550.07     D        D3
# 49993   36 months     13.59      1019.37     C        C2
# 49994   36 months     15.05       277.52     C        C4
# 49995   60 months     18.06       330.54     D        D2
# 49996   60 months     13.59       276.68     C        C2
# 49997   60 months     15.05       476.33     C        C4
# 49998   36 months      7.35       217.27     A        A4
# 49999   36 months     13.59       203.88     C        C2
#
#                                    emp_title emp_length home_ownership  \
# 0                                   mechanic    6 years       MORTGAGE
# 1                                        NaN        NaN            OWN
# 2                               Truck driver  10+ years            OWN
# 3                     Confidential Secretary    2 years           RENT
# 4                            General Manager   < 1 year           RENT
# 5                                    NDT III  10+ years           RENT
# 6                Supervisory program analyst  10+ years       MORTGAGE
# 7                Commercial Property Manager   < 1 year       MORTGAGE
# 8                       Equipment technician   < 1 year       MORTGAGE
# 9                                        NaN        NaN            OWN
# 10             IT Manager - Business Process  10+ years            OWN
# 11                 Strategic Account Manager     1 year       MORTGAGE
# 12                           Account Manager    5 years           RENT
# 13                           sales associate    2 years            OWN
# 14                          Machine operator    4 years           RENT
# 15                            Vice President    3 years           RENT
# 16                      Installation Manager  10+ years       MORTGAGE
# 17                             Senior Agent     2 years           RENT
# 18                         commercial sales   10+ years            OWN
# 19                                     sales  10+ years           RENT
# 20                Assistant General Manager     4 years           RENT
# 21                   Control System Designer    2 years            OWN
# 22                                   Teacher  10+ years       MORTGAGE
# 23                                Consultant    4 years           RENT
# 24                            Office manager    5 years           RENT
# 25                         Probation Officer  10+ years           RENT
# 26                            Showroom Sales     1 year       MORTGAGE
# 27                                    Server    5 years           RENT
# 28                                       EMT    5 years       MORTGAGE
# 29                            Policy Analyst   < 1 year           RENT
# ...                                      ...        ...            ...
# 49970                                    ASA    2 years           RENT
# 49971                    Stationary Engineer  10+ years       MORTGAGE
# 49972                              PRESIDENT   < 1 year       MORTGAGE
# 49973                          ADMINISTRATOR    4 years       MORTGAGE
# 49974                    Executive Assistant    2 years           RENT
# 49975                        General manager  10+ years       MORTGAGE
# 49976                                 Nanny    < 1 year           RENT
# 49977               Customer Service Manager    4 years       MORTGAGE
# 49978                     restaurant manager    5 years           RENT
# 49979                                  Owner    2 years            OWN
# 49980                                    NaN        NaN       MORTGAGE
# 49981                                    NaN        NaN           RENT
# 49982                            Captain/EMT  10+ years       MORTGAGE
# 49983                                     PO  10+ years            OWN
# 49984                                    NaN        NaN            OWN
# 49985                                janitor   < 1 year       MORTGAGE
# 49986                  Physical Therapy Aide    4 years            OWN
# 49987                                teacher   < 1 year       MORTGAGE
# 49988  Senior VP & Chief Information Officer  10+ years       MORTGAGE
# 49989                         Title searcher    7 years           RENT
# 49990                           Radiographer  10+ years       MORTGAGE
# 49991              Aviation Maintenance Tech  10+ years       MORTGAGE
# 49992                          Administrator   < 1 year            OWN
# 49993                               Attorney  10+ years       MORTGAGE
# 49994                             Bartender     9 years           RENT
# 49995                    Clinical Supervisor  10+ years           RENT
# 49996                             consultant    2 years           RENT
# 49997                      Controls Engineer    2 years       MORTGAGE
# 49998                           Hair Stylist   < 1 year           RENT
# 49999                         Store manager      1 year           RENT
#
#        annual_inc verification_status   issue_d         loan_status  \
# 0         80000.0        Not Verified  Dec-2017             Current
# 1         90000.0        Not Verified  Dec-2017             Current
# 2        168000.0        Not Verified  Dec-2017             Current
# 3         39000.0     Source Verified  Dec-2017             Current
# 4         55000.0        Not Verified  Dec-2017             Current
# 5         74000.0        Not Verified  Dec-2017             Current
# 6        140000.0        Not Verified  Dec-2017             Current
# 7         48000.0        Not Verified  Dec-2017             Current
# 8         38000.0        Not Verified  Dec-2017             Current
# 9         76000.0            Verified  Dec-2017             Current
# 10       140000.0            Verified  Dec-2017             Current
# 11       325000.0     Source Verified  Dec-2017     In Grace Period
# 12        62000.0        Not Verified  Dec-2017             Current
# 13        22000.0     Source Verified  Dec-2017          Fully Paid
# 14        35000.0     Source Verified  Dec-2017             Current
# 15       270000.0     Source Verified  Dec-2017          Fully Paid
# 16        75000.0     Source Verified  Dec-2017             Current
# 17        26685.0            Verified  Dec-2017  Late (31-120 days)
# 18        40000.0     Source Verified  Dec-2017             Current
# 19        75000.0     Source Verified  Dec-2017             Current
# 20        38500.0            Verified  Dec-2017         Charged Off
# 21       149000.0            Verified  Dec-2017             Current
# 22        54000.0            Verified  Dec-2017             Current
# 23        99000.0            Verified  Dec-2017          Fully Paid
# 24        41000.0            Verified  Dec-2017         Charged Off
# 25        93400.0     Source Verified  Dec-2017             Current
# 26        54000.0        Not Verified  Dec-2017             Current
# 27        40000.0     Source Verified  Dec-2017             Current
# 28        52000.0     Source Verified  Dec-2017          Fully Paid
# 29        44000.0        Not Verified  Dec-2017             Current
# ...           ...                 ...       ...                 ...
# 49970     70000.0     Source Verified  Nov-2017          Fully Paid
# 49971     70000.0        Not Verified  Nov-2017             Current
# 49972     80000.0        Not Verified  Nov-2017          Fully Paid
# 49973    126109.0        Not Verified  Nov-2017          Fully Paid
# 49974     80000.0        Not Verified  Nov-2017             Current
# 49975     79040.0        Not Verified  Nov-2017             Current
# 49976     36000.0        Not Verified  Nov-2017             Current
# 49977    110000.0     Source Verified  Nov-2017             Current
# 49978     70000.0        Not Verified  Nov-2017             Current
# 49979    127000.0     Source Verified  Nov-2017             Current
# 49980     65000.0            Verified  Nov-2017          Fully Paid
# 49981     65000.0     Source Verified  Nov-2017             Current
# 49982     67000.0     Source Verified  Nov-2017             Current
# 49983    200000.0     Source Verified  Nov-2017             Current
# 49984     48000.0            Verified  Nov-2017             Current
# 49985     71900.0     Source Verified  Nov-2017             Current
# 49986     27800.0        Not Verified  Nov-2017             Current
# 49987     35000.0     Source Verified  Nov-2017         Charged Off
# 49988    165000.0     Source Verified  Nov-2017             Current
# 49989     80000.0        Not Verified  Nov-2017          Fully Paid
# 49990     43000.0        Not Verified  Nov-2017             Current
# 49991    100000.0            Verified  Nov-2017             Current
# 49992     38000.0        Not Verified  Nov-2017         Charged Off
# 49993    115000.0            Verified  Nov-2017             Current
# 49994     55000.0     Source Verified  Nov-2017             Current
# 49995     60000.0        Not Verified  Nov-2017             Current
# 49996     90000.0        Not Verified  Nov-2017          Fully Paid
# 49997    105000.0        Not Verified  Nov-2017             Current
# 49998     30000.0            Verified  Nov-2017             Current
# 49999     50000.0        Not Verified  Nov-2017          Fully Paid
#
#       pymnt_plan  url  desc             purpose                    title  \
# 0              n  NaN   NaN         credit_card  Credit card refinancing
# 1              n  NaN   NaN               other                    Other
# 2              n  NaN   NaN               other                    Other
# 3              n  NaN   NaN         credit_card  Credit card refinancing
# 4              n  NaN   NaN  debt_consolidation       Debt consolidation
# 5              n  NaN   NaN  debt_consolidation       Debt consolidation
# 6              n  NaN   NaN  debt_consolidation       Debt consolidation
# 7              n  NaN   NaN               other                    Other
# 8              n  NaN   NaN  debt_consolidation       Debt consolidation
# 9              n  NaN   NaN         credit_card  Credit card refinancing
# 10             n  NaN   NaN  debt_consolidation       Debt consolidation
# 11             n  NaN   NaN  debt_consolidation       Debt consolidation
# 12             n  NaN   NaN  debt_consolidation       Debt consolidation
# 13             n  NaN   NaN  debt_consolidation       Debt consolidation
# 14             n  NaN   NaN  debt_consolidation       Debt consolidation
# 15             n  NaN   NaN         credit_card  Credit card refinancing
# 16             n  NaN   NaN  debt_consolidation       Debt consolidation
# 17             n  NaN   NaN              moving    Moving and relocation
# 18             n  NaN   NaN  debt_consolidation       Debt consolidation
# 19             n  NaN   NaN         credit_card  Credit card refinancing
# 20             n  NaN   NaN  debt_consolidation       Debt consolidation
# 21             n  NaN   NaN               other                    Other
# 22             n  NaN   NaN  debt_consolidation       Debt consolidation
# 23             n  NaN   NaN  debt_consolidation       Debt consolidation
# 24             n  NaN   NaN  debt_consolidation       Debt consolidation
# 25             n  NaN   NaN  debt_consolidation       Debt consolidation
# 26             n  NaN   NaN    home_improvement         Home improvement
# 27             n  NaN   NaN  debt_consolidation       Debt consolidation
# 28             n  NaN   NaN  debt_consolidation       Debt consolidation
# 29             n  NaN   NaN  debt_consolidation       Debt consolidation
# ...          ...  ...   ...                 ...                      ...
# 49970          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49971          n  NaN   NaN    home_improvement         Home improvement
# 49972          n  NaN   NaN         credit_card  Credit card refinancing
# 49973          n  NaN   NaN               other                    Other
# 49974          n  NaN   NaN         credit_card  Credit card refinancing
# 49975          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49976          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49977          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49978          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49979          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49980          n  NaN   NaN    home_improvement         Home improvement
# 49981          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49982          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49983          n  NaN   NaN      major_purchase           Major purchase
# 49984          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49985          n  NaN   NaN    home_improvement         Home improvement
# 49986          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49987          n  NaN   NaN    home_improvement         Home improvement
# 49988          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49989          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49990          n  NaN   NaN         credit_card  Credit card refinancing
# 49991          n  NaN   NaN         credit_card  Credit card refinancing
# 49992          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49993          n  NaN   NaN         credit_card  Credit card refinancing
# 49994          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49995          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49996          n  NaN   NaN         credit_card  Credit card refinancing
# 49997          n  NaN   NaN  debt_consolidation       Debt consolidation
# 49998          n  NaN   NaN         credit_card  Credit card refinancing
# 49999          n  NaN   NaN         credit_card  Credit card refinancing
#
#       zip_code addr_state    dti  delinq_2yrs earliest_cr_line  \
# 0        762xx         TX  14.82            0         Jul-2007
# 1        295xx         SC  28.51            0         Jun-2002
# 2        788xx         TX  11.62            0         Aug-2002
# 3        125xx         NY  22.88            0         Apr-2003
# 4        672xx         KS  12.18            0         Jun-1999
# 5        920xx         CA  21.46            0         Apr-2001
# 6        750xx         TX   7.76            2         May-1988
# 7        936xx         CA  16.66            0         Mar-2006
# 8        765xx         TX  14.28            0         Oct-2008
# 9        388xx         MS  34.28            0         Aug-1994
# 10       292xx         SC  31.79            1         Aug-1999
# 11       027xx         MA  14.12            0         Nov-2003
# 12       010xx         MA  14.65            0         Aug-2004
# 13       439xx         OH  31.21            0         Feb-2008
# 14       635xx         MO  15.26            0         Dec-2008
# 15       945xx         CA   8.25            0         Mar-1996
# 16       585xx         ND  27.64            0         Dec-2002
# 17       331xx         FL  23.12            0         Sep-2011
# 18       394xx         MS   7.74            0         Nov-1986
# 19       197xx         DE   9.50            0         Mar-2004
# 20       799xx         TX  30.94            0         Apr-2007
# 21       770xx         TX  13.31            0         Jul-1999
# 22       630xx         MO  47.44            0         Nov-1990
# 23       301xx         GA  14.61            0         Mar-2003
# 24       274xx         NC  21.36            0         Dec-2013
# 25       791xx         TX  17.20            2         Nov-2002
# 26       461xx         IN  27.16            0         Jul-2005
# 27       912xx         CA  26.92            1         Feb-2006
# 28       935xx         CA  26.10            0         Sep-2004
# 29       973xx         OR  17.21            0         Sep-2008
# ...        ...        ...    ...          ...              ...
# 49970    212xx         MD  25.17            0         Aug-2007
# 49971    212xx         MD  14.25            0         Sep-2007
# 49972    857xx         AZ  20.13            0         Aug-2000
# 49973    630xx         MO  25.56            0         Oct-1994
# 49974    208xx         MD  21.32            0         Apr-2007
# 49975    331xx         FL  15.75            0         Nov-2004
# 49976    114xx         NY   3.20            0         May-2009
# 49977    352xx         AL   6.87            0         Aug-2004
# 49978    940xx         CA   8.38            0         Apr-2005
# 49979    714xx         LA   8.02            0         Nov-2011
# 49980    985xx         WA  28.62            0         Apr-2003
_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0             8        0       5225        73.6         30
# 1            12        3       6953        51.9         38
# 2             4        0       3401        97.2         12
# 3             8        0      12918        59.5         16
# 4             5        0       4497        91.8          6
# 5             5        0      22328        83.3         19
# 6             9        0      21374        62.0         24
# 7             9        0      12748        91.7         11
# 8             6        0       1381        21.6          7
# 9            23        0      47145        48.0         42
# 10           11        0      34632        59.5         52
# 11           16        0      28674        81.7         38
# 12            9        0       6363        37.4         15
# 13           15        0       1799         4.6         20
# 14            6        0       4238        26.2         19
# 15            5        0      16087        96.9         14
# 16           14        0      21795        56.6         22
# 17            4        0       3083        28.0          5
# 18            3        0       5742        13.9         10
# 19            7        1       8265        62.6         12
# 20           13        0      11305        68.9         18
# 21           16        0       5049         5.3         27
# 22           11        1      15078        30.2         32
# 23           12        0      13666        65.7         16
# 24            7        0       3669        18.7          8
# 25           14        0      10847        49.8         35
# 26           18        0      17410        25.9         28
# 27            8        0       7897        75.2         16
# 28            7        1       5967        72.8         27
# 29            8        0       9929        38.0         25
# ...         ...      ...        ...         ...        ...
# 49970        10        0      14938        53.9         33
# 49971         5        0       1991        94.8         11
# 49972         9        0      10402        42.8         13
# 49973        13        0         43         0.7         30
# 49974         7        0      19147        65.3          9
# 49975         9        0      14279        66.7         17
# 49976         5        0        835        10.1          5
# 49977         4        0      10995       100.0          9
# 49978        12        0       8958        14.4         18
# 49979         9        0      10720        28.1         14
# 49980        11        1       8549        46.7         16
# 49981        13        0       9658        43.1         49
# 49982        11        0      27482        63.6         25
# 49983        15        0     109607        72.2         48
# 49984         5        0      26228        46.0         22
# 49985         2        0          0         0.0          4
# 49986         5        0       5370        39.2          6
# 49987        10        0         13         0.1         27
# 49988        21        0      47560        58.0         28
# 49989         5        0       8174        52.1          9
# 49990        11        0       7348        24.7         19
# 49991         6        0      50357        69.8          9
# 49992        19        0      13255        29.7         37
# 49993         7        0      33991        88.3         11
# 49994        12        1       9646        32.2         18
# 49995        25        0      12046        35.3         44
# 49996        12        0      16142        29.1         25
# 49997         9        0       4791        51.0         34
# 49998        11        0       6654        15.7         28
# 49999        14        0       6500        38.7         15
#
#       initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                       w    6442.28        6442.28   4493.810000
# 1                       w    2266.55        2266.55   1586.770000
# 2                       w    3291.95        3291.95   2371.050000
# 3                       w    9090.87        9090.87   6391.530000
# 4                       w    3291.95        3291.95   2371.050000
# 5                       w   29698.80       29698.80  11691.920000
# 6                       w   12933.83       12933.83   9035.820000
# 7                       w    2077.66        2077.66   1472.580000
# 8                       w    9613.67        9613.67   7201.930000
# 9                       w   22139.93       22139.93  14900.920000
# 10                      w   33288.83       33288.83  13602.030000
# 11                      w   15060.28       15060.28   5368.080000
# 12                      w     750.33         750.33   6002.550000
# 13                      w       0.00           0.00  19243.700856
# 14                      w    6662.23        6662.23   4745.710000
# 15                      w       0.00           0.00  29679.376794
# 16                      w   19390.68       19390.68   8309.650000
# 17                      w    8787.42        8787.42   3369.630000
# 18                      w    9832.57        9832.57   3773.110000
# 19                      w    1009.98        1009.98    767.450000
# 20                      f       0.00           0.00   3810.120000
# 21                      w   12651.33       12651.33   8470.960000
# 22                      w   25903.99       25903.99  18258.280000
# 49972         0.0                      0.0     Apr-2018         16502.96
# 49973         0.0                      0.0     Sep-2018          7718.35
# 49974         0.0                      0.0     Feb-2019           662.20
# 49975         0.0                      0.0     Feb-2019           469.84
# 49976         0.0                      0.0     Feb-2019           100.54
# 49977         0.0                      0.0     Feb-2019           498.02
# 49978         0.0                      0.0     Feb-2019           451.73
# 49979         0.0                      0.0     Feb-2019           676.78
# 49980         0.0                      0.0     May-2018          2243.12
# 49981         0.0                      0.0     Feb-2019           357.25
# 49982         0.0                      0.0     Feb-2019           939.68
# 49983         0.0                      0.0     Feb-2019           259.72
# 49984         0.0                      0.0     Feb-2019          1130.68
# 49985         0.0                      0.0     Feb-2019           373.52
# 49986         0.0                      0.0     Feb-2019           186.23
# 49987         0.0                      0.0     Sep-2018           698.01
# 49988         0.0                      0.0     Feb-2019           372.77
# 49989         0.0                      0.0     Aug-2018         32130.26
# 49990         0.0                      0.0     Feb-2019           227.55
# 49991         0.0                      0.0     Feb-2019           838.91
# 49992        50.0                      9.0     Jan-2019            50.00
# ...
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# 5                                 NaN                           NaN
# 6                                 NaN                           NaN
# 7                                 NaN                           NaN
# 8                                 NaN                           NaN
# 9                                 NaN                           NaN
# 10                                NaN                           NaN
# 11                                NaN                           NaN
# 12                                NaN                           NaN
# 13                                NaN                           NaN
# 14                                NaN                           NaN
# 15                                NaN                           NaN
# 16                                NaN                           NaN
# 17                                NaN                           NaN
# 18                                NaN                           NaN
# 19                                NaN                           NaN
# 20                                NaN                           NaN
# 21                                NaN                           NaN
# 22                                NaN                           NaN
# 23                                NaN                           NaN
# 24                                NaN                           NaN
# 25                                NaN                           NaN
# 26                                NaN                           NaN
# 27                                NaN                           NaN
# 28                                NaN                           NaN
# 29                                NaN                           NaN
# ...                               ...                           ...
# 49970                             NaN                           NaN
# 49971                             NaN                           NaN
# 49972                             NaN                           NaN
# 49973                             NaN                           NaN
# 49974                             NaN                           NaN
# 49975                             NaN                           NaN
# 49976                             NaN                           NaN
# 49977                             NaN                           NaN
# 49978                             NaN                           NaN
# 49979                             NaN                           NaN
# 49980                             NaN                           NaN
# 49981                             NaN                           NaN
# 49982                             NaN                           NaN
# 49983                             NaN                           NaN
# 49984                             NaN                           NaN
# 49985                             NaN                           NaN
# 49986                             NaN                           NaN
# 49987                             NaN                           NaN
# 49988                             NaN                           NaN
# 49989                             NaN                           NaN
# 49990                             NaN                           NaN
# 49991                             NaN                           NaN
# 49992                             NaN                           NaN
# 49993                             NaN                           NaN
# 49994                             NaN                           NaN
# 49995                             NaN                           NaN
# 49996                             NaN                           NaN
# 49997                             NaN                           NaN
# 49998                             NaN                           NaN
# 49999                             NaN                           NaN
#
#       disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 0                    Cash                    N                       NaN
# 1                    Cash                    N                       NaN
# 2                    Cash                    N                       NaN
# 3                    Cash                    N                       NaN
# 4                    Cash                    N                       NaN
# 5                    Cash                    N                       NaN
# 6                    Cash                    N                       NaN
# 7                    Cash                    N                       NaN
# 8                    Cash                    N                       NaN
# 9               DirectPay                    N                       NaN
# 10                   Cash                    N                       NaN
# 11                   Cash                    N                       NaN
# 12                   Cash                    N                       NaN
# 13                   Cash                    N                       NaN
# 14                   Cash                    N                       NaN
# 15                   Cash                    N                       NaN
# 16                   Cash                    N                       NaN
# 17                   Cash                    N                       NaN
# 18                   Cash                    N                       NaN
# 19                   Cash                    N                       NaN
# 20                   Cash                    N                       NaN
# 21                   Cash                    N                       NaN
# 22                   Cash                    N                       NaN
# 23                   Cash                    N                       NaN
# 24                   Cash                    N                       NaN
# 25                   Cash                    N                       NaN
# 26                   Cash                    N                       NaN
# 27                   Cash                    N                       NaN
# 28                   Cash                    N                       NaN
# 29                   Cash                    N                       NaN
# ...                   ...                  ...                       ...
# 49970                Cash                    N                       NaN
# 49971                Cash                    N                       NaN
# 49972                Cash                    N                       NaN
# 49973                Cash                    N                       NaN
# 49974                Cash                    N                       NaN
# 49975                Cash                    N                       NaN
# 49976                Cash                    N                       NaN
# 49977                Cash                    N                       NaN
# 49978                Cash                    N                       NaN
# 49979                Cash                    N                       NaN
# 49980                Cash                    N                       NaN
# 49981                Cash                    N                       NaN
# 49982                Cash                    N                       NaN
# 49983                Cash                    N                       NaN
# 49984                Cash                    N                       NaN
# 49985                Cash                    N                       NaN
# 49986                Cash                    N                       NaN
# 49987                Cash                    N                       NaN
# 49988                Cash                    N                       NaN
# 49989                Cash                    N                       NaN
# 49990           DirectPay                    N                       NaN
# 49991                Cash                    N                       NaN
# 49992                Cash                    Y                  Nov-2018
# 49993                Cash                    N                       NaN
# 49994                Cash                    N                       NaN
# 49995                Cash                    N                       NaN
# 49996                Cash                    N                       NaN
# 49997                Cash                    N                       NaN
# 49998                Cash                    N                       NaN
# 49999                Cash                    N                       NaN
#
#       settlement_status settlement_date  settlement_amount  \
# 0                   NaN             NaN                NaN
# 1                   NaN             NaN                NaN
# 2                   NaN             NaN                NaN
# 3                   NaN             NaN                NaN
# 4                   NaN             NaN                NaN
# 5                   NaN             NaN                NaN
# 6                   NaN             NaN                NaN
# 7                   NaN             NaN                NaN
# 8                   NaN             NaN                NaN
# 9                   NaN             NaN                NaN
# 10                  NaN             NaN                NaN
# 11                  NaN             NaN                NaN
# 12                  NaN             NaN                NaN
# 13                  NaN             NaN                NaN
# 14                  NaN             NaN                NaN
# 15                  NaN             NaN                NaN
# 16                  NaN             NaN                NaN
# 17                  NaN             NaN                NaN
# 18                  NaN             NaN                NaN
# 19                  NaN             NaN                NaN
# 20                  NaN             NaN                NaN
# 21                  NaN             NaN                NaN
# 22                  NaN             NaN                NaN
# 23                  NaN             NaN                NaN
# 24                  NaN             NaN                NaN
# 25                  NaN             NaN                NaN
# 26                  NaN             NaN                NaN
# 27                  NaN             NaN                NaN
# 28                  NaN             NaN                NaN
# 29                  NaN             NaN                NaN
# ...                 ...             ...                ...
# 49970               NaN             NaN                NaN
# 49971               NaN             NaN                NaN
# 49972               NaN             NaN                NaN
# 49973               NaN             NaN                NaN
# 49974               NaN             NaN                NaN
# 49975               NaN             NaN                NaN
# 49976               NaN             NaN                NaN
# 49977               NaN             NaN                NaN
# 49978               NaN             NaN                NaN
# 49979               NaN             NaN                NaN
# 49980               NaN             NaN                NaN
# 49981               NaN             NaN                NaN
# 49982               NaN             NaN                NaN
# 49983               NaN             NaN                NaN
# 49984               NaN             NaN                NaN
# 49985               NaN             NaN                NaN
# 49986               NaN             NaN                NaN
# 49987               NaN             NaN                NaN
# 49988               NaN             NaN                NaN
# 49989               NaN             NaN                NaN
# 49990               NaN             NaN                NaN
# 49991               NaN             NaN                NaN
# 49992            ACTIVE        Nov-2018             7578.0
# 49993               NaN             NaN                NaN
# 49994               NaN             NaN                NaN
# 49995               NaN             NaN                NaN
# 49996               NaN             NaN                NaN
# 49997               NaN             NaN                NaN
# 49998               NaN             NaN                NaN
# 49999               NaN             NaN                NaN
#
#        settlement_percentage  settlement_term
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# 5                        NaN              NaN
# 6                        NaN              NaN
# 7                        NaN              NaN
# 8                        NaN              NaN
# 9                        NaN              NaN
# 10                       NaN              NaN
# 11                       NaN              NaN
# 12                       NaN              NaN
# 13                       NaN              NaN
# 14                       NaN              NaN
# 15                       NaN              NaN
# 16                       NaN              NaN
# 17                       NaN              NaN
# 18                       NaN              NaN
# 19                       NaN              NaN
# 20                       NaN              NaN
# 21                       NaN              NaN
# 22                       NaN              NaN
# 23                       NaN              NaN
# 24                       NaN              NaN
# 25                       NaN              NaN
# 26                       NaN              NaN
# 27                       NaN              NaN
# 28                       NaN              NaN
# 29                       NaN              NaN
# ...                      ...              ...
# 49970                    NaN              NaN
# 49971                    NaN              NaN
# 49972                    NaN              NaN
# 49973                    NaN              NaN
# 49974                    NaN              NaN
# 49975                    NaN              NaN
# 49976                    NaN              NaN
# 49977                    NaN              NaN
# 49978                    NaN              NaN
# 49979                    NaN              NaN
# 49980                    NaN              NaN
# 49981                    NaN              NaN
# 49982                    NaN              NaN
# 49983                    NaN              NaN
# 49984                    NaN              NaN
# 49985                    NaN              NaN
# 49986                    NaN              NaN
# 49987                    NaN              NaN
# 49988                    NaN              NaN
# 49989                    NaN              NaN
# 49990                    NaN              NaN
# 49991                    NaN              NaN
# 49992                   60.0             18.0
# 49993                    NaN              NaN
# 49994                    NaN              NaN
# 49995                    NaN              NaN
# 49996                    NaN              NaN
# 49997                    NaN              NaN
# 49998                    NaN              NaN
# 49999                    NaN              NaN
#
# [50000 rows x 146 columns]

# %% [markdown]
# ### 사용 데이터 간략 설명
#     미국 핀테크 회사인 lending club의 대출 데이터베이스
#     핀테크의 시초라고 부를 수 있는 회사
#     방대한 양의 대출정보를 공개하면서 금융정보분석에도 기여한 공이 큰 데이터
#     2007 ~ 2015 년 대출정보 및 개인정보를 담고 있음
#     226만건, 145항목 정보를 담고있음
#     실습데이터는 이 중 5만건을 추출한 데이터를 사용합니다.
#
# 데이터출처: https://www.kaggle.com/wendykan/lending-club-loan-data

# %% [markdown]
# ### 데이터 살펴보기

# %%
# 데이터를 불러들인 후 가장 처음 하는 작업
# 데이터의 구조, 형태 파악하기
# 데이터의 첫 5개 샘플 확인하기
df.head()
# 10개를 확인하려면?

# %%
# 데이터의 마지막 5개 샘플 확인하기
# 데이터가 잘 가져왔는지 확인 할 때 보통 씁니다.
df.tail()

# %%
# 데이터의 갯수를 살펴봅니다
len(df)

# %%
# 데이터의 전반적인 정보를 확인합니다.
df.info()
# dtype 정보에서는 각 컬럼별 데이터 타입을 확인 할 수 있습니다.
# object == str 이라고 생각하셔도 무방합니다.
# verbose, null_counts

# %%
# 데이터의 기초통계량을 확인합니다.
df.describe()

# %%
# numpy 함수로 데이터 shape 확인
np.shape(df)

# %%
# 인덱스
df.index

# %%
# 컬럼
df.columns

# %% [markdown]
# 데이터셋을 살펴 본 결과 정체를 알 수 없는 많은 컬럼이 있는 걸 확인했고,
#
# 50000개의 샘플이 불러들여진 것을 확인 할 수 있었습니다.
#
# 추가로 데이터 중간 중간 비어있는 값도 있는 것을 확인했습니다.

# %% [markdown]
# ### 데이터접근 (인덱싱, 슬라이싱, 샘플링)

# %%
# 첫 샘플 혹은 레코드(대출건)에 대한 데이터를 살펴보겠습니다.
# 인덱스넘버로 데이터에 접근하는 .iloc[색인]
df.iloc[0]

# %%
# 10번 인덱스 부터 20번 인덱스 샘플 접근
df.iloc[10:20]

# %%
# 첫번째 0, 10, 20 인덱스 샘플 접근
df.iloc[[0, 10, 20]]

# %%
# 컬럼 단위 샘플 접근
df['emp_title']

# %%
# 여러 컬럼 동시 접근
df[['emp_title', 'grade']]

# %%
# row와 columns을 동시에 슬라이싱 하는 속성
# df.loc[인덱스, 컬럼명]
df.loc[10:20, ['emp_title', 'grade']]

# %% [markdown]
# 기본적인 인덱싱 방법에 추가로 조건에 따른 데이터 샘플링도 가능합니다.

# %%
# 조건식 샘플링
df[df['emp_title'] == 'ceo']

# %%
# 신용등급 A와 B인 샘플접근
df[(df['grade'] == 'A') | (df['grade'] == 'B')]
# 조건식을 여러개 써야 한다면 조건마다 ()로 감싸주시는 것이 좋습니다.

# %%
# installment 구하기
# 계산상으로는 비슷한 결과가 나오지만 정확한 수치는 조금 더 디테일한 부분을 신경써야 할 듯
# 혹시 계산 도움을 주실 수 있으면 좋습니다.
# 참고용
loan = 10000
term = 36
rate = 0.0944
for i in range(0, 36):
    payment = loan / -(i - term)
    interests = loan * (rate / 12)
    loan -= payment
    print(payment + interests)

# %% [markdown]
# ## 2. 데이터프레임 병합
#     실제 분석업무를 진행하다보면 데이터가 여기저기 분산되어 있을 경우가 더 많습니다.
#     조각난 데이터를 분석에 필요한 데이터셋으로 만들기 위해 데이터프레임 병합을 많이 사용합니다.
#     한개 이상의 데이터프레임을 병합 할 때 주로 사용하는 함수 2가지를 알아보겠습니다.

# %% [markdown]
# #### 데이터 병합에 사용가능한 key(병합할 기준이 되는 행 or 열)값이 있는경우
#     pd.merge(베이스데이터프레임, 병합할데이터프레임)
#
#     사용가능한 파라메터
#     - how : 'left', 'right', 'inner', 'outer'
#     - left_on : key값이 다를 경우 베이스데이터프레임의 key 설정
#     - right_on : key값이 다를 경우 병합데이터프레임의 key 설정
#
# #### 단순 데이터 연결
#     pd.concat([베이스데이터프레임, 병합할데이터프레임], axis=0 or 1)

# %% [markdown]
# ### merge, concat 예시

# %%
merge_df1 = pd.DataFrame({
    '이름': ['원영', '사쿠라', '유리', '예나', '유진', '나코', '은비', '혜원', '히토미', '채원', '민주', '째욘'],
    '국어': [100, 70, 70, 70, 60, 90, 90, 70, 70, 80, 100, 100],
    '영어': [100, 90, 80, 50, 70, 100, 70, 90, 100, 100, 80, 100]
    }, columns=['이름', '국어', '영어']) 

merge_df2 = pd.DataFrame({
    '일어': [80, 100, 100, 90, 70, 50, 100],
    '수학': [90, 70, 100, 80, 70, 80, 90],
    '이름': ['원영', '사쿠라', '나코', '히토미', '예나', '은비', '째욘'],
    }, columns=['일어', '수학', '이름'])

# %% [markdown]
# ### concat으로 데이터 이어붙이기
#     현재 df에 저장되어있는 데이터에 추가로 5만개의 데이터를 이어붙여보겠습니다.
#     df1이라는 변수에 이어붙일 데이터를 불러들여 병합을 진행해보겠습니다.

# %%
# df1 변수에 loan2.csv 파일을 읽어들입니다.
df1 = pd.read_csv('loan2.csv')
# 데이터프레임 확인
# df1

# %%
# df 와 df1 shape 확인
df.shape, df1.shape

# %%
# 데이터프레임 행단위 병합
df = pd.concat([df, df1])

# %%
# 병합 데이터프레임 shape 확인
df.shape

# %%
# 데이터 확인
df.tail()

# %% [markdown]
# ## 3. 인덱스 조작
#     방금 전 concat으로 병합한 데이터프레임의 이상한 점을 찾으셨나요?
#     데이터 자체는 잘 붙였지만 인덱스가 꼬여있습니다.
#     인덱스 조작은 데이터분석을 위해 필요한 인덱스를 설정하기 위해 필요합니다.

# %%
# 인덱스 초기화
df = df.reset_index()
# df

# %%
# 기존 컬럼값을 취해 index로 사용
df.set_index('index', inplace=True)

# %%
# 기존 인덱스값을 날리면서 인덱스 초기화
df = df.reset_index(drop=True)

# %% [markdown]
# ## 4. 컬럼조작
#     인덱스 조작과 마찬가지로 데이터프레임의 컬럼을 변경해야 할 경우도 있습니다.
#     데이터프레임은 컬럼단위 샘플링 및 인덱싱, 이름변경이 가능합니다.

# %% [markdown]
# ### 컬럼선택

# %%
# df 컬럼명 접근
df.columns

# %%
# columns 속성도 인덱싱 및 슬라이싱이 가능합니다.
df.columns[0:26]

# %% [markdown]
# 저는 개인정보에 관한 부분에 관심이 생겼습니다. 데이터셋 중 필요한 부분만을 컬럼단위로 추려보겠습니다.

# %%
# df의 개인정보에 관한 컬럼만을 색인으로 df를 슬라이싱하고 person_df 변수에 바인딩
person_df = df[df.columns[0:26]]
person_df

# %% [markdown]
# ### 컬럼삭제
# 현재 데이터셋에는 개인식별정보가 지워져서 데이터가 존재하지 않습니다. 불필요한 데이터 column을 지우도록 하겠습니다.

# %%
# 지울 column의 데이터값이 모두 NaN인지 확인
person_df['id'].sum(), person_df['member_id'].sum(), person_df['url'].sum(), person_df['desc'].sum()

# %% [markdown]
# 삭제할 컬럼 모두 데이터가 없는 것을 확인했습니다.

# %%
# 컬럼삭제 drop('컬럼명', axis=1)
# del (df['컬럼명'])
# 실제로는 컬럼 및 행도 삭제 가능합니다. axis=0(기본값)
# inplace=True 파라메터를 사용해서 원본값을 변경가능합니다.
person_df = person_df.drop('id', axis=1)
# person_df = person_df.drop('id', axis=1)

# %%
# inplace 파라메터 사용
person_df.drop('member_id', axis=1, inplace=True)

# %%
# del 메모리 삭제 키워드 사용
del person_df['url']
del person_df['desc']

# %%
person_df

# %% [markdown]
# ### 컬럼명 변경
#     경우에 따라서는 데이터셋 제작 중 컬럼명을 변경해야 할 경우도 있습니다.
#     국내 수집 데이터 사용 시 컬럼이 한글일 경우 영어로 변경을 많이 합니다.

# %%
# home_ownership을 간략하게 home으로 변경
# 한글도 가능합니다만 권장하지는 않습니다.
person_df.rename(columns={'home_ownership' : 'home'}, inplace=True)

# %%
person_df

# %% [markdown]
# ## 5. 데이터 샘플링
#     데이터 병합, 인덱스 조작, 컬럼 선택만으로도 불필요한 정보를 삭제하고
#     새롭게 데이터셋을 만들 수 있는것을 확인했습니다.
#     위에 학습한 내용도 데이터 샘플링에 속한 내용이지만
#     지금부터는 데이터셋의 데이터를 살펴보면서 의미있는 데이터를 추려보도록 하겠습니다.
#
# #### 데이터프레임의 기본적인 인덱싱, 슬라이싱, 조건부 샘플링을 조합하면 데이터의 샘플을 확인 하는 과정만으로도 데이터분석이 가능해집니다.
# 이후 노트북 진행

# %%
# 분석에 필요한 데이터프레임을 만들었으니 원본값을 사용하겠습니다. 기존 df에 person_df 값을 덮어 씌웁니다.
df = person_df
df.to_csv('loan_df.csv')

# %% [markdown]
# #### 저는 채권자의 개인정보에 관심이 많습니다. 고객의 직업을 살펴보겠습니다.

# %%
df['emp_title']

# %%
# 값을 카운트 하는 함수 value_counts()
df['emp_title'].value_counts()

# %%
# Owner, owner 같은 직업이지만 대소문자 구분에 따라 다른 값으로 취급되는 문제가 있네요.
# 대소문자 구분을 없애기 위해 모두 소문자로 데이터값을 변경하겠습니다.
# 소문자 변환 전 혹시모를 int, float 데이터가 있을지 모를 상황에 대비해서 모두 문자열로 변경해주겠습니다.
# 형변환 함수 astype(데이터타입)
df['emp_title'] = df['emp_title'].astype(str)

# %%
# %%time
# 반복문을 사용한 데이터 변경도 가능
# 하지만 파이썬의 강점을 살리지 못한 코드
for index, title in enumerate(df['emp_title']):
    df['emp_title'][index] = title.lower()

# %% [markdown]
# ### 배운사람들의 코드, 고오급 python 스킬
#     numpy를 학습하면서 브로드캐스팅에 관하여 잠깐 언급했었습니다.
#     그렇다만 그 파워풀하다던 브로드캐스팅은 어떻게 사용해야할까요?
#
#     기타 언어에서는 지원하지 않는 기능이니만큼 파이썬의 특징을 가장 잘 살리는 코드
#     apply 함수를 사용하여 인자로 받는 모든 데이터에 함수를 적용

# %% [markdown]
# #### apply 함수로 컬럼에 적용시키는 코드 구조
#     df['컬럼명'] = df['컬럼명'].apply(lambda x: func(x) if 조건문)

# %%
# %%time
# apply() 함수사용 반복이 가능한 데이터구조의 모든 인자에 적용
# lambda 각 인자에 적용할 함수 혹은 연산
df['emp_title'] = df['emp_title'].apply(lambda x: x.lower())

# %%
# 대소문자 구분을 처리한 값 확인
df['emp_title'].value_counts()
# 기존 value_count 값과 차이가 있음을 확인 할 수 있습니다.
# 제공 된 데이터셋이라도 이와 같은 작은 차이가 있을 수 있습니다.
# 데이터를 꼼꼼하게 살펴볼 수록 디테일한 차이를 만들 수 있습니다.

# %%
# owner인 사람들 샘플링
df[df['emp_title'] == 'owner']

# %%
# 샘플링 된 데이터프레임의 단일 컬럼 접근
df[df['emp_title'] == 'owner']['annual_inc']

# %%
# 컬럼 평균값 계산
df[df['emp_title'] == 'ceo']['annual_inc'].mean()

# %%
# 코드 하나 변경으로 간단한 분석 가능
# owner가 아닌 사람들의 평균
df[df['emp_title'] != 'owner']['annual_inc'].mean()

# %%
# 각 직업별 평균연봉이 궁금하다
# 엑셀의 pivol table 과 비슷한 기능
df.groupby('emp_title').mean()

# %%
# 위 테이블에서 연간수입 접근
df.groupby('emp_title').mean()['annual_inc']

# %%
# 데이터정렬
df.groupby('emp_title').mean()['annual_inc'].sort_values(ascending=False)

# %% [markdown]
# ## 6. 결측치 처리
#     데이터 분석을 위해서는 데이터셋 내에 빈 값이 있는 경우 분석에 방해가 될 수 있는 여지가 많습니다.
#     모든 결측치를 없애야 하는 것은 아니지만 되도록이면 결측치를 채우는 방법, 혹은 없애는 방법등으로 결측치를 처리합니다.
#     몇가지 예시를 살펴보면서 결측치 처리에 대해 알아봅시다.

# %%
# info() 함수는 결측치에 대한 정보도 보여줍니다.
# 컬럼별 isnull() 함수를 사용해도 무방합니다.
df.info()

# %% [markdown]
#     확인결과 emp_title, emp_length, dti에 결측치가 존재합니다.
#     해당 컬럼의 결측치 샘플들을 살펴보고 결측치를 처리해 보겠습니다.

# %%
# 컬럼별 결측치 확인을 위한 isnull()함수 리턴값이 bool 형태로 반환되어 조건부 샘플링이 가능합니다.
df['emp_title'].isnull().head()

# %%
len(df) - df['emp_title'].isnull().sum()

# %%
df[df['emp_title'].isnull()]

# %%
df[df['dti'].isnull()]

# %% [markdown]
#     직업과 근속연수에 관한 부분은 데이터를 통한 유추나 계산값을 통해 채워넣을 수 있는 항목은 아닌 것 같습니다.
#     다만 dti의 경우 실수로 채워져 있는 부분이니 수업을 위해 평균값 혹은 근사치를 계산하여 채워보도록 하겠습니다.

# %% [markdown]
# ### 결측치 채우기

# %%
# dti 컬럼의 NaN값 index 확인
df[df['dti'].isnull()].index

# %%
# fillna() 함수로 NaN 값을 dti 컬럼의 평균으로 채우기
df['dti'].fillna(df['dti'].mean(), inplace=True) # inplace 파라메터 사용가능
# fillna() 함수의 다양한 채우기 방법 파라메터 확인해보기

# %% [markdown]
# ### 결측치 제거

# %%
df[df['emp_title'].isnull()]

# %%
df.info()

# %%
df.dropna().info()

# %%
df.dropna(inplace=True)

# %%
df.info()
