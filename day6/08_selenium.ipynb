# %% [markdown]
# # 데이터 크롤링

# %% [markdown]
# ## 1. 셀레니움
#
#     웹 어플리케이션 테스트를 위한 프레임워크.
#
#     다양한 브라우저 작동을 지원하며 크롤링에도 활용가능.
#
#     정적, 동적페이지 크롤링으로도 접근이 불가능한 데이터에 접근할 때 유용하게 사용
#
#     현존하는 거의 모든 웹브라우저를 다양한 언어를 통해 제어 가능

# %% [markdown]
# ## 2. 셀레니움 Setting
#
#     사용해야 하는 브라우저의 웹드라이버 다운 필요
#
#     크롬 환경설정 -> 크롬 정보로 크롬 버전 확인 필요
#
#     크롬 드라이버 다운로드
# https://chromedriver.chromium.org/downloads
#
#     셀레니움은 이 웹 드라이버 API를 제어하는 파이썬 패키지입니다.

# %%
# 셀레니움 설치
# !pip3 install selenium
# Out:
# 'pip3'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
from selenium import webdriver

# %% [markdown]
# ## 간단한 브라우저 컨트롤로 기본 개념잡기

# %%
driver = webdriver.Chrome('./chromedriver.exe')

# %%
url = 'https://www.naver.com/'
driver.get(url)
driver.find_element_by_xpath('//*[@id="query"]').send_keys('해운대 암소갈비\n')
driver.find_element_by_xpath('//*[@id="lnb"]/div/div[1]/ul/li[5]/a/span').click()

# %%
news_list=driver.find_elements_by_css_selector('a')

# %%
news_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="ebf77749-1abf-4017-8268-bc2cfa94d94c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="2f0df231-988f-461c-9091-9f515c01c937")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="e20e71eb-a321-44ca-bd80-0510858a3c0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="3816ccea-056d-4f89-b788-495966fc20ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="92b137be-27fd-4df0-8f64-3b5b25bd9b8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d18f59153edd3d2ebd1f28f1fbcb9b", element="1008948f-3aec-46a0-a557-e4210d85eb8b")>,
# ...

# %%
# 스크립트 형태로 전달
driver.execute_script('document.getElementById("id").value = "km4233"')
driver.execute_script('document.getElementById("pw").value = "theowalcott20804"')
driver.find_element_by_xpath('//*[@id="log.login"]').click()
# 스크롤다운
#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
url = 'https://www.naver.com/'
driver.get(url)

# %%
##얘가 주소가 됨. xpath 주소임.
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys('min9yuth')
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys('theowalcott20804\n')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-70-2cb6eec9f78e> in <module>
#       1 ##얘가 주소가 됨. xpath 주소임.
# ----> 2 driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys('min9yuth')
#       3 driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys('theowalcott31004!\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %%
import time
url = 'https://www.instagram.com/'
driver.get(url)

time.sleep(2)

driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys("min9yuth")
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input').send_keys("theowalcott31004\n")
time.sleep(5)
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-95-b3523e179252> in <module>
#       5 time.sleep(2)
#       6
# ----> 7 driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input').send_keys("min9yuth")
#       8 driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input').send_keys("theowalcott31004\n")
#       9 time.sleep(5)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %%
driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input').send_keys("해운대암소갈비\n")

# %%
driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[3]/div[2]/div/a[1]/div').click()

# %%
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[2]/a/div[1]/div[2]').click()

# %%
cup=driver.find_elements_by_css_selector('a.xil3i')

# %%
#인스타그램 해시태그 크롤링 (행렬로 되어있음 주의.)
for i in range(1,5):
    for j in range(1,4):
        print(i,j)
        driver.find_element_by_xpath(f'//*[@id="react-root"]/section/main/article/div[2]/div/div[{i}]/div[{j}]/a/div[1]/div[2]').click()
        print("g")
        time.sleep(3)
        cup=driver.find_elements_by_css_selector('a.xil3i')
        tag_list = []
        num =0
        for item in cup:
            print(item.text)
            if num >= 10:
                tag_list.append(item.text)
            num+=1
        tag_list
        driver.find_element_by_xpath('/html/body/div[4]/div[3]/button').click()
        time.sleep(3)
# Out:
# 1 1
# g
#
#
#
#
#
#
#
#
#
#
# #sujinkyu_2020
# #부산
# #해운대
# #시그니엘부산
# #샹테카이스파
# #인피니티풀
# #데이비드목컴
# #수진규
# #해운대암소갈비
# #honeymoon
# #신혼여행
# #풀바
# #오션뷰호텔
# 1 2
# g
#
#
#
#
#
#
#
#
#
#
# 1 3
# g
#
#
#
#
#
#
#
#
#
#
# #부산여행
# #카페히토
# #해운대암소갈비
# #영국이네
# #해운대바닷가
# #동백섬
# 2 1
# g
#
#
#
#
#
#
#
#
#
#
# #부산
# #해운대암소갈비
# #해운대암소갈비집
# #daily
# #instadaily
# 2 2
# g
#
#
#
#
#
#
#
#
#
#
# #해운대암소갈비
# #갈비맛집
# 2 3
# g
#
#
#
#
#
#
#
#
#
#
# #백화양곱창
# #영도포장마차
# #해운대암소갈비
# #송도키친
# #영진돼지국밥
# #신발원
# 3 1
# g
#
#
#
#
#
#
#
#
#
#
# #해운대암소갈비
# #인생갈비
# #생갈비
# #고기육즙대박
# #팡팡
# #여긴매일오고싶을정도
# #감자면
# #쵸코네❤️
# 3 2
# g
#
#
#
#
#
#
#
#
#
#
# #해운대
# #부산맛집
# #부산
# #해운대암소갈비
# #밀양국밥
# #돼지국밥
# #맛집
# #맛스타그램
# #고기
# #소고기
# #갈비
# #힐링
# 3 3
# g
#
#
#
#
#
#
#
#
#
#
# #해운대암소갈비
# #해운대소문난암소갈비
# #다이어트는망했고
# #해운대맛집
# #해운대맛집추천
# #해운대고기집
# #해운대갈비
# #더먹을수도있지만참았고
# #😋
# 4 1
# g
#
#
#
#
#
#
#
#
#
#
# #규우정
# ...

# %%
cup[0].text
# Out:
# '#베짱이'

# %%
tag_list = []
num =0
for item in cup:
    print(item.text)
    if num >= 10:
        tag_list.append(item.text)
    num+=1
tag_list
# Out:
# #베짱이
# #서방님
# #성북
# #비내리는밤
# #디져트맛집
# #나들이스타그램
# #최애메뉴
# #미분당
# #먹방시작
# #콘샐러드
# #부산
# #맛집
# #해운대암소갈비
# ['#부산', '#맛집', '#해운대암소갈비']

# %%
import time
url = 'https://www.instagram.com/'
driver.get(url)
driver.execute_script('document.getElementById("id").value = "min9yuth"')
driver.execute_script('document.getElementById("pw").value = "theowalcott31004"')
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[4]').click()
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# <ipython-input-83-45415fde15df> in <module>
#       2 url = 'https://www.instagram.com/'
#       3 driver.get(url)
# ----> 4 driver.execute_script('document.getElementById("id").value = "min9yuth"')
#       5 driver.execute_script('document.getElementById("pw").value = "theowalcott31004"')
#       6 driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[4]').click()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ...
